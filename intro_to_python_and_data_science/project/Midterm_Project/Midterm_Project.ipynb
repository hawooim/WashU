# %% [markdown]
# # Smart Logistic System in Walmart

# %% [markdown]
# ### Note:
#
# 1. This is a group-based project, you are only allowed to discuss with your team members.
#
# 2. You are not allowed to use any packages to read or write csv files.

# %%
import numpy as np   #Numpy package would be the only package you could use for this project.

# %% [markdown]
# ## Problem1: The Estimated Value for Each Warehouse
# #### Note that you are not allowed to use dynamic programming in this problem!

# %% [markdown]
# In this problem 1, calculating the estimated total value and accumulated weight of each of 300 warehouses will be helpful for the later decision of cross-warehouse-transshipment solution in problem 2.

# %% [markdown]
# ### Step 1: Estimate the Maximized Total Value and Accumulated Weight of One Warehouse

# %% [markdown]
# Read the dataset from  "Products.csv" first.

# %%
file_name='Products.csv'

#write your codes here
with open(file_name, 'r') as f:
    products = f.readlines()
    
    # Drop unnecessary lines of ',,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,\n'
    products = [i.strip('\n').split(',') for i in products if i != ',,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,\n']
    
    # Convert strings to float 
    products = [[float(num) for num in i] for i in products]

# %%
# Check the code above
print(f"The length of the Weight-Value list: {len(products)} \n")  # 600 = (Weight line + Value line) * 300
print(f"Weights of each product of the 0th warehouse: \n{products[0]} \n")
print(f"Values of each product of the 0th warehouse: \n{products[1]} \n")
# Out:
# The length of the Weight-Value list: 600
#
# Weights of each product of the 0th warehouse:
# [112.0, 100.0, 108.0, 66.0, 95.0, 91.0, 35.0, 49.0, 27.0, 91.0, 99.0, 27.0, 71.0, 95.0, 55.0, 113.0, 59.0, 3.0, 20.0, 25.0, 40.0, 48.0, 49.0, 23.0, 48.0, 72.0, 72.0, 39.0, 53.0, 11.0, 71.0, 56.0, 119.0, 42.0, 6.0, 114.0, 66.0, 83.0, 38.0, 45.0, 16.0, 20.0, 67.0, 77.0, 9.0, 26.0, 3.0, 117.0, 60.0, 49.0]
#
# Values of each product of the 0th warehouse:
# [66.0, 170.66, 130.0, 67.32, 65.48, 27.08, 65.0, 17.23, 44.05, 34.92, 121.4, 4.12, 28.5, 65.52, 98.53, 89.46, 73.92, 3.26, 25.84, 23.28, 32.14, 27.79, 38.83, 26.12, 3.09, 160.1, 91.58, 19.4, 50.56, 5.81, 33.1, 49.63, 28.32, 44.49, 5.35, 93.4, 20.7, 146.5, 63.39, 10.1, 11.78, 20.46, 79.58, 123.3, 6.35, 21.88, 4.79, 119.31, 23.0, 35.33]

# %% [markdown]
# Now let's get the estimated value and weight for one warehouse.You need to write a function "get_max_value" which could do the following 4 things:
# 1. Calculate the Value_Weight Ratio for each product.
# 2. Sort the calculated Value_Weight Ratios in descending order.
# 3. Select the products from the top of the descending order to the bottom while looking at the accumulated         weight of products to make sure the accumulated weight does not exceed the warehouse weight capacity.
# 4. Calculate the  corresponding estimated value for this warehouse after finishing product selection.
#
# Remember, take every product into consideration; otherwise, you may have the risk of missing products. You want to put as many product with highest Value_Weight Ratio as possible before reaching the weight capacity for this warehouse.

# %%
def get_max_value(products, i):  # i means ith warehouse (i = 0 ~ 299)
    
    #write your codes here
    
    # Define 'weights', 'values' from 'products'
    weights = products[i*2]  # 0th, 2nd, ..., 598th lines 
    values = products[i*2 + 1]  # 1st, 3rd, ..., 599th lines
    
    # Define 'vw_ratios' (Value-Weight Ratios)
    vw_ratios = np.array(values) / np.array(weights)  # Convert to numpy array for calculation
    vw_ratios = vw_ratios.tolist()                    # Convert back to list

    # Define 'vw_ratios_desc' (Value-Weight Ratios in descending order)
    vw_ratios_desc = sorted(vw_ratios, reverse=True)  

    # Define empty lists for for loop
    selected_indices = []
    selected_weights = []
    selected_values = []

    # For loop
    for vw_ratio in vw_ratios_desc:
        index = vw_ratios.index(vw_ratio)                  # define product index
    
        if sum(selected_weights) + weights[index] <= 650:
            selected_indices.append(index)                 # get selected products' indices
            selected_weights.append(weights[index])        # get selected products' weights
            selected_values.append(values[index])          # get selected products' values

        else:
            continue
    
    # Print the results (optional)
    print(f"For {i}th warehouse, selected products are: \n{selected_indices} \n")
    print(f"For {i}th warehouse, selected products' weights are: \n{selected_weights} \n")
    print(f"For {i}th warehouse, selected products' values are: \n{selected_values} \n")
    
    print(f"For {i}th warehouse, The Total Weight is: {sum(selected_weights)}")
    print(f"For {i}th warehouse, The Total Value is: {sum(selected_values)}")
    
    # Return [The Total Weight, The Total Value, None]
    # 'None' here is for later use (a place for value-per-weight in Problem2)
    return [sum(selected_weights), sum(selected_values), None]

# %%
# Check the code above
get_max_value(products, 0)
# Make sure you have calculated the total Value and accumulated Weight for One Warehouse
# Again, 'None' here is for later use (a place for value-per-weight in Problem2)
# Out:
# For 0th warehouse, selected products are:
# [25, 6, 14, 37, 1, 38, 8, 43, 46, 18, 26, 16, 17, 34]
#
# For 0th warehouse, selected products' weights are:
# [72.0, 35.0, 55.0, 83.0, 100.0, 38.0, 27.0, 77.0, 3.0, 20.0, 72.0, 59.0, 3.0, 6.0]
#
# For 0th warehouse, selected products' values are:
# [160.1, 65.0, 98.53, 146.5, 170.66, 63.39, 44.05, 123.3, 4.79, 25.84, 91.58, 73.92, 3.26, 5.35]
#
# For 0th warehouse, The Total Weight is: 650.0
# For 0th warehouse, The Total Value is: 1076.2699999999998
# [650.0, 1076.2699999999998, None]

# %% [markdown]
# ### Step 2: Estimate the Total Value for 300 Warehouses
# Let's apply the same calculation process of step 1 for one warehouse to the 299 warehouses left.
#
# Keep in mind that calculating the estimated total value and accumulated weight of 300 warehouses will be helpful for the later decision of cross-warehouse-transshipment solution in problem 2.

# %%
#write your codes here

# Define 'warehouse_value' as dictionary
warehouse_value = {}

# Fill 'warehouse_value' (itreate 0 ~ 299, instead of 0 ~ 899 by 3)
for i in range(300):
    #write your codes here
    warehouse_value[i] = get_max_value(products, i)
# Out:
# For 0th warehouse, selected products are:
# [25, 6, 14, 37, 1, 38, 8, 43, 46, 18, 26, 16, 17, 34]
#
# For 0th warehouse, selected products' weights are:
# [72.0, 35.0, 55.0, 83.0, 100.0, 38.0, 27.0, 77.0, 3.0, 20.0, 72.0, 59.0, 3.0, 6.0]
#
# For 0th warehouse, selected products' values are:
# [160.1, 65.0, 98.53, 146.5, 170.66, 63.39, 44.05, 123.3, 4.79, 25.84, 91.58, 73.92, 3.26, 5.35]
#
# For 0th warehouse, The Total Weight is: 650.0
# For 0th warehouse, The Total Value is: 1076.2699999999998
# For 1th warehouse, selected products are:
# [39, 7, 38, 27, 13, 49, 31, 33, 17, 37, 47, 44, 3]
#
# For 1th warehouse, selected products' weights are:
# [32.0, 56.0, 34.0, 86.0, 118.0, 93.0, 58.0, 17.0, 26.0, 99.0, 18.0, 7.0, 4.0]
#
# For 1th warehouse, selected products' values are:
# [63.52, 101.94, 60.37, 144.48, 165.97, 129.91, 80.99, 23.58, 35.69, 135.54, 24.18, 7.0, 3.61]
#
# For 1th warehouse, The Total Weight is: 648.0
# For 1th warehouse, The Total Value is: 976.78
# For 2th warehouse, selected products are:
# [31, 8, 35, 23, 24, 48, 7, 10, 37, 15, 4]
#
# For 2th warehouse, selected products' weights are:
# [34.0, 41.0, 56.0, 58.0, 42.0, 78.0, 112.0, 104.0, 108.0, 3.0, 8.0]
#
# For 2th warehouse, selected products' values are:
# [76.5, 89.65, 117.44, 120.33, 85.14, 154.39, 220.79, 185.95, 174.25, 3.51, 3.75]
#
# For 2th warehouse, The Total Weight is: 644.0
# For 2th warehouse, The Total Value is: 1231.7
# For 3th warehouse, selected products are:
# [30, 5, 32, 21, 45, 43, 14, 41, 9, 35, 26, 20, 49, 48, 40]
#
# For 3th warehouse, selected products' weights are:
# [61.0, 32.0, 34.0, 81.0, 124.0, 22.0, 11.0, 17.0, 69.0, 113.0, 9.0, 59.0, 5.0, 8.0, 4.0]
#
# For 3th warehouse, selected products' values are:
# [122.03, 55.25, 57.83, 136.83, 209.14, 35.3, 16.95, 26.02, 97.02, 149.14, 11.42, 74.07, 4.53, 6.96, 1.0]
#
# For 3th warehouse, The Total Weight is: 649.0
# For 3th warehouse, The Total Value is: 1003.49
# For 4th warehouse, selected products are:
# [20, 7, 45, 24, 43, 46, 38, 47, 13, 49, 8, 28]
#
# For 4th warehouse, selected products' weights are:
# [26.0, 117.0, 48.0, 31.0, 47.0, 53.0, 109.0, 46.0, 111.0, 45.0, 10.0, 2.0]
#
# For 4th warehouse, selected products' values are:
# [54.68, 221.23, 90.14, 56.39, 84.22, 91.62, 187.9, 71.59, 162.52, 64.48, 12.84, 2.36]
#
# For 4th warehouse, The Total Weight is: 645.0
# For 4th warehouse, The Total Value is: 1099.9699999999998
# For 5th warehouse, selected products are:
# [21, 49, 3, 20, 26, 44, 28, 39, 32, 2, 45, 6, 47, 12, 27, 35, 22]
#
# For 5th warehouse, selected products' weights are:
# [47.0, 32.0, 56.0, 123.0, 12.0, 18.0, 53.0, 63.0, 16.0, 108.0, 85.0, 18.0, 1.0, 8.0, 2.0, 7.0, 1.0]
#
# For 5th warehouse, selected products' values are:
# [95.83, 56.25, 95.12, 200.47, 19.1, 27.54, 79.75, 92.71, 23.11, 154.31, 119.05, 25.11, 1.37, 10.35, 2.21, 6.6, 0.3]
#
# For 5th warehouse, The Total Weight is: 650.0
# For 5th warehouse, The Total Value is: 1009.1800000000001
# For 6th warehouse, selected products are:
# [31, 6, 45, 43, 5, 25, 29, 40, 44, 12]
#
# For 6th warehouse, selected products' weights are:
# [62.0, 122.0, 95.0, 104.0, 94.0, 40.0, 72.0, 52.0, 6.0, 1.0]
#
# For 6th warehouse, selected products' values are:
# [135.09, 261.64, 181.73, 179.09, 159.63, 67.7, 121.47, 86.2, 3.36, 0.54]
#
# For 6th warehouse, The Total Weight is: 648.0
# For 6th warehouse, The Total Value is: 1196.45
# For 7th warehouse, selected products are:
# [35, 37, 14, 47, 11, 1, 32, 48, 0, 33, 12, 44, 21, 3]
#
# For 7th warehouse, selected products' weights are:
# [68.0, 79.0, 78.0, 52.0, 49.0, 24.0, 31.0, 98.0, 73.0, 63.0, 6.0, 8.0, 1.0, 17.0]
#
# For 7th warehouse, selected products' values are:
# [119.65, 135.85, 128.56, 84.96, 79.3, 37.8, 44.49, 136.91, 98.44, 80.63, 7.31, 8.83, 0.76, 11.63]
#
# For 7th warehouse, The Total Weight is: 647.0
# For 7th warehouse, The Total Value is: 975.1199999999998
# For 8th warehouse, selected products are:
# [19, 1, 24, 7, 2, 42, 34, 26, 48, 0, 10, 9, 5, 29, 13, 36, 30]
#
# For 8th warehouse, selected products' weights are:
# [46.0, 7.0, 73.0, 52.0, 6.0, 111.0, 34.0, 19.0, 6.0, 16.0, 42.0, 109.0, 35.0, 67.0, 13.0, 7.0, 5.0]
#
# For 8th warehouse, selected products' values are:
# [96.06, 13.61, 135.84, 92.32, 10.4, 173.69, 52.99, 29.31, 9.14, 23.88, 61.77, 151.12, 46.96, 86.15, 16.26, 5.99, 3.9]
#
# For 8th warehouse, The Total Weight is: 648.0
# For 8th warehouse, The Total Value is: 1009.3899999999999
# For 9th warehouse, selected products are:
# [19, 0, 18, 45, 49, 42, 37, 10, 39, 38, 46, 5, 20]
#
# For 9th warehouse, selected products' weights are:
# [110.0, 26.0, 9.0, 48.0, 116.0, 8.0, 65.0, 30.0, 31.0, 120.0, 55.0, 13.0, 18.0]
#
# For 9th warehouse, selected products' values are:
# [223.61, 48.9, 16.08, 79.44, 187.08, 12.87, 100.1, 45.73, 46.84, 180.97, 82.89, 18.12, 11.37]
#
# For 9th warehouse, The Total Weight is: 649.0
# For 9th warehouse, The Total Value is: 1054.0
# For 10th warehouse, selected products are:
# [36, 48, 32, 14, 27, 46, 43, 12, 35, 7, 42]
#
# For 10th warehouse, selected products' weights are:
# [14.0, 70.0, 81.0, 68.0, 84.0, 108.0, 35.0, 119.0, 22.0, 31.0, 14.0]
#
# For 10th warehouse, selected products' values are:
# [27.05, 118.04, 122.12, 102.12, 123.86, 156.58, 50.37, 166.66, 29.27, 37.47, 14.49]
#
# For 10th warehouse, The Total Weight is: 646.0
# For 10th warehouse, The Total Value is: 948.0300000000001
# For 11th warehouse, selected products are:
# [34, 45, 40, 39, 16, 5, 22, 41, 21, 18, 46, 15, 25]
#
# For 11th warehouse, selected products' weights are:
# [32.0, 123.0, 14.0, 81.0, 57.0, 116.0, 6.0, 63.0, 93.0, 38.0, 14.0, 4.0, 7.0]
#
# For 11th warehouse, selected products' values are:
# [65.62, 245.79, 25.52, 140.12, 97.82, 197.41, 9.65, 97.49, 143.38, 52.27, 17.63, 4.29, 5.17]
#
# For 11th warehouse, The Total Weight is: 648.0
# For 11th warehouse, The Total Value is: 1102.16
# For 12th warehouse, selected products are:
# [16, 25, 6, 5, 48, 43, 26, 35, 17, 8, 40]
#
# For 12th warehouse, selected products' weights are:
# [89.0, 76.0, 33.0, 111.0, 124.0, 99.0, 32.0, 24.0, 45.0, 14.0, 1.0]
#
# For 12th warehouse, selected products' values are:
# [179.99, 147.73, 63.99, 200.58, 211.62, 159.64, 49.81, 35.53, 65.95, 17.26, 1.02]
#
# For 12th warehouse, The Total Weight is: 648.0
# For 12th warehouse, The Total Value is: 1133.1200000000001
# For 13th warehouse, selected products are:
# [22, 38, 3, 17, 43, 45, 40, 27, 7, 26, 16, 31, 30]
#
# For 13th warehouse, selected products' weights are:
# [122.0, 66.0, 112.0, 72.0, 2.0, 18.0, 54.0, 96.0, 47.0, 16.0, 1.0, 19.0, 20.0]
#
# For 13th warehouse, selected products' values are:
# [260.07, 123.05, 195.71, 125.01, 3.4, 30.03, 88.06, 152.9, 64.21, 21.0, 1.28, 23.33, 22.63]
#
# For 13th warehouse, The Total Weight is: 645.0
# For 13th warehouse, The Total Value is: 1110.6799999999998
# For 14th warehouse, selected products are:
# [3, 18, 44, 26, 9, 22, 12, 11, 37, 47, 32, 6, 48, 17]
#
# For 14th warehouse, selected products' weights are:
# [72.0, 71.0, 57.0, 16.0, 124.0, 56.0, 90.0, 3.0, 115.0, 20.0, 2.0, 3.0, 6.0, 9.0]
#
# For 14th warehouse, selected products' values are:
# [112.37, 109.09, 87.47, 24.5, 185.11, 83.03, 130.58, 4.31, 158.58, 27.27, 2.3, 2.86, 4.63, 6.05]
#
# For 14th warehouse, The Total Weight is: 644.0
# For 14th warehouse, The Total Value is: 938.1499999999999
# For 15th warehouse, selected products are:
# [1, 23, 10, 3, 20, 33, 36, 34, 18, 24, 17, 7, 32]
#
# For 15th warehouse, selected products' weights are:
# [28.0, 115.0, 2.0, 15.0, 76.0, 118.0, 26.0, 13.0, 15.0, 49.0, 74.0, 99.0, 4.0]
#
# For 15th warehouse, selected products' values are:
# [64.7, 238.44, 4.07, 26.94, 126.45, 191.43, 41.62, 20.32, 22.64, 71.19, 107.12, 141.56, 2.82]
#
# For 15th warehouse, The Total Weight is: 634.0
# For 15th warehouse, The Total Value is: 1059.3
# For 16th warehouse, selected products are:
# [8, 20, 39, 1, 44, 36, 10, 11, 23, 2, 17, 33, 26]
#
# For 16th warehouse, selected products' weights are:
# [41.0, 112.0, 65.0, 2.0, 45.0, 31.0, 28.0, 103.0, 81.0, 101.0, 37.0, 2.0, 2.0]
#
# For 16th warehouse, selected products' values are:
# [94.7, 238.8, 132.14, 3.77, 84.02, 55.25, 46.39, 169.64, 133.12, 159.33, 52.35, 2.65, 2.23]
#
# For 16th warehouse, The Total Weight is: 650.0
# For 16th warehouse, The Total Value is: 1174.3899999999999
# For 17th warehouse, selected products are:
# [0, 6, 28, 17, 11, 43, 40, 45, 2, 32, 27, 10, 23, 18]
#
# For 17th warehouse, selected products' weights are:
# [78.0, 37.0, 41.0, 3.0, 55.0, 55.0, 10.0, 3.0, 116.0, 65.0, 54.0, 115.0, 12.0, 5.0]
#
# For 17th warehouse, selected products' values are:
# [167.07, 65.79, 71.73, 4.98, 83.49, 83.14, 14.98, 4.41, 169.47, 92.25, 73.76, 156.34, 9.09, 0.67]
#
# For 17th warehouse, The Total Weight is: 649.0
# For 17th warehouse, The Total Value is: 997.1700000000001
# For 18th warehouse, selected products are:
# [8, 2, 17, 16, 32, 12, 35, 37, 49, 0, 36, 42, 11]
#
# For 18th warehouse, selected products' weights are:
# [33.0, 68.0, 49.0, 89.0, 94.0, 24.0, 16.0, 122.0, 95.0, 14.0, 34.0, 2.0, 1.0]
#
# For 18th warehouse, selected products' values are:
# [76.73, 121.67, 84.68, 142.8, 150.61, 36.12, 23.23, 176.92, 123.76, 17.61, 41.13, 2.26, 0.55]
#
# For 18th warehouse, The Total Weight is: 641.0
# For 18th warehouse, The Total Value is: 998.0699999999999
# For 19th warehouse, selected products are:
# [35, 17, 40, 42, 19, 46, 45, 37, 9, 5, 26]
#
# For 19th warehouse, selected products' weights are:
# [1.0, 8.0, 59.0, 38.0, 118.0, 85.0, 112.0, 65.0, 43.0, 2.0, 111.0]
#
# For 19th warehouse, selected products' values are:
# [1.95, 14.73, 102.82, 65.88, 190.59, 129.75, 164.84, 95.16, 62.9, 2.89, 155.4]
#
# For 19th warehouse, The Total Weight is: 642.0
# For 19th warehouse, The Total Value is: 986.91
# For 20th warehouse, selected products are:
# [41, 25, 20, 16, 49, 18, 24, 9, 44, 26, 37, 21, 12, 42]
#
# For 20th warehouse, selected products' weights are:
# [21.0, 121.0, 95.0, 84.0, 7.0, 80.0, 7.0, 87.0, 5.0, 32.0, 70.0, 18.0, 7.0, 16.0]
#
# For 20th warehouse, selected products' values are:
# [45.93, 261.68, 190.14, 163.93, 13.61, 153.74, 12.9, 152.63, 8.56, 53.32, 109.52, 25.96, 10.07, 19.08]
#
# For 20th warehouse, The Total Weight is: 650.0
# For 20th warehouse, The Total Value is: 1221.07
# For 21th warehouse, selected products are:
# [3, 7, 41, 25, 35, 16, 27, 4, 37, 15, 42, 29, 47, 12]
#
# For 21th warehouse, selected products' weights are:
# [31.0, 108.0, 117.0, 81.0, 36.0, 20.0, 11.0, 12.0, 110.0, 27.0, 16.0, 68.0, 3.0, 9.0]
#
# For 21th warehouse, selected products' values are:
# [56.96, 195.74, 197.67, 136.07, 58.99, 29.87, 16.13, 17.34, 157.9, 38.3, 21.85, 91.61, 4.02, 10.4]
#
# For 21th warehouse, The Total Weight is: 649.0
# For 21th warehouse, The Total Value is: 1032.8500000000001
# For 22th warehouse, selected products are:
# [43, 19, 35, 18, 45, 6, 49, 36, 32, 31, 7, 23, 15, 38, 5, 0]
#
# For 22th warehouse, selected products' weights are:
# [27.0, 107.0, 76.0, 112.0, 11.0, 10.0, 38.0, 97.0, 39.0, 4.0, 48.0, 12.0, 21.0, 5.0, 20.0, 21.0]
#
# For 22th warehouse, selected products' values are:
# [51.84, 191.05, 130.48, 184.79, 17.99, 15.87, 60.1, 151.46, 59.91, 6.13, 72.46, 16.75, 29.22, 6.9, 26.46, 25.51]
#
# For 22th warehouse, The Total Weight is: 648.0
# For 22th warehouse, The Total Value is: 1046.92
# For 23th warehouse, selected products are:
# [27, 15, 40, 22, 20, 11, 32, 34, 21, 13, 30]
#
# For 23th warehouse, selected products' weights are:
# [86.0, 59.0, 71.0, 48.0, 49.0, 103.0, 69.0, 15.0, 48.0, 77.0, 24.0]
#
# For 23th warehouse, selected products' values are:
# [185.04, 119.51, 137.87, 74.73, 74.26, 155.69, 103.81, 21.88, 69.25, 108.18, 26.01]
#
# For 23th warehouse, The Total Weight is: 649.0
# For 23th warehouse, The Total Value is: 1076.2299999999998
# For 24th warehouse, selected products are:
# [4, 18, 31, 28, 3, 27, 37, 36, 10, 44, 38, 11]
#
# For 24th warehouse, selected products' weights are:
# [44.0, 116.0, 120.0, 82.0, 54.0, 39.0, 11.0, 114.0, 31.0, 14.0, 7.0, 15.0]
#
# For 24th warehouse, selected products' values are:
# [81.39, 211.6, 217.23, 141.33, 92.0, 65.13, 17.15, 176.09, 46.7, 19.1, 7.53, 15.36]
#
# For 24th warehouse, The Total Weight is: 647.0
# For 24th warehouse, The Total Value is: 1090.61
# For 25th warehouse, selected products are:
# [39, 3, 18, 16, 45, 38, 42, 13, 36, 49, 46, 23, 28, 7]
#
# For 25th warehouse, selected products' weights are:
# [81.0, 10.0, 115.0, 4.0, 44.0, 90.0, 24.0, 51.0, 80.0, 66.0, 66.0, 4.0, 3.0, 12.0]
#
# For 25th warehouse, selected products' values are:
# [156.18, 19.18, 214.14, 7.43, 78.39, 155.57, 39.84, 82.66, 119.73, 96.27, 84.3, 4.94, 3.59, 12.34]
#
# For 25th warehouse, The Total Weight is: 650.0
# For 25th warehouse, The Total Value is: 1074.56
# For 26th warehouse, selected products are:
# [43, 26, 4, 49, 24, 37, 32, 1, 38, 17, 5, 19]
#
# For 26th warehouse, selected products' weights are:
# [35.0, 48.0, 120.0, 29.0, 82.0, 15.0, 58.0, 48.0, 116.0, 86.0, 9.0, 3.0]
#
# For 26th warehouse, selected products' values are:
# [71.85, 85.89, 206.71, 46.44, 130.61, 23.84, 89.19, 73.57, 176.25, 130.54, 13.27, 2.75]
#
# For 26th warehouse, The Total Weight is: 649.0
# For 26th warehouse, The Total Value is: 1050.9099999999999
# For 27th warehouse, selected products are:
# [5, 12, 25, 41, 32, 1, 24, 47, 22, 13, 16, 10, 30, 27, 42, 4, 36, 48]
#
# For 27th warehouse, selected products' weights are:
# [24.0, 93.0, 33.0, 16.0, 107.0, 96.0, 80.0, 17.0, 79.0, 43.0, 7.0, 30.0, 7.0, 3.0, 2.0, 4.0, 4.0, 4.0]
#
# For 27th warehouse, selected products' values are:
# [46.01, 177.82, 61.94, 28.54, 187.6, 161.73, 125.67, 26.68, 123.36, 64.0, 10.18, 41.03, 8.74, 3.52, 2.08, 4.01, 3.85, 2.6]
#
# For 27th warehouse, The Total Weight is: 649.0
# For 27th warehouse, The Total Value is: 1079.3599999999997
# For 28th warehouse, selected products are:
# [20, 21, 27, 45, 8, 10, 7, 6, 28, 37, 43, 26, 23]
#
# For 28th warehouse, selected products' weights are:
# [8.0, 87.0, 80.0, 93.0, 48.0, 19.0, 35.0, 84.0, 87.0, 52.0, 12.0, 30.0, 11.0]
#
# For 28th warehouse, selected products' values are:
# [18.86, 191.17, 147.65, 163.0, 77.9, 30.43, 55.69, 115.82, 115.8, 68.88, 14.48, 33.09, 7.56]
#
# For 28th warehouse, The Total Weight is: 646.0
# For 28th warehouse, The Total Value is: 1040.3299999999997
# For 29th warehouse, selected products are:
# [40, 14, 5, 41, 26, 48, 15, 44, 35, 2, 33, 21]
#
# For 29th warehouse, selected products' weights are:
# [83.0, 40.0, 43.0, 119.0, 94.0, 92.0, 66.0, 87.0, 10.0, 4.0, 3.0, 6.0]
#
# For 29th warehouse, selected products' values are:
# [193.59, 76.74, 75.09, 194.7, 150.94, 142.76, 94.41, 114.0, 11.74, 4.11, 3.03, 2.43]
#
# For 29th warehouse, The Total Weight is: 647.0
# For 29th warehouse, The Total Value is: 1063.54
# For 30th warehouse, selected products are:
# [32, 49, 45, 12, 44, 2, 36, 20, 41, 24, 38, 14]
#
# For 30th warehouse, selected products' weights are:
# [92.0, 113.0, 15.0, 104.0, 51.0, 62.0, 102.0, 46.0, 7.0, 20.0, 19.0, 7.0]
#
# For 30th warehouse, selected products' values are:
# [168.78, 196.6, 25.69, 174.98, 82.45, 99.57, 159.97, 64.74, 9.18, 24.25, 22.48, 7.45]
#
# For 30th warehouse, The Total Weight is: 638.0
# For 30th warehouse, The Total Value is: 1036.1399999999999
# For 31th warehouse, selected products are:
# [5, 13, 38, 23, 12, 21, 19, 20, 0, 32, 10, 1, 49]
#
# For 31th warehouse, selected products' weights are:
# [70.0, 59.0, 12.0, 61.0, 77.0, 77.0, 102.0, 124.0, 3.0, 21.0, 37.0, 1.0, 6.0]
#
# For 31th warehouse, selected products' values are:
# [138.12, 112.54, 21.5, 94.35, 117.2, 116.39, 150.29, 179.41, 4.16, 28.63, 49.7, 1.21, 6.45]
#
# For 31th warehouse, The Total Weight is: 650.0
# For 31th warehouse, The Total Value is: 1019.95
# For 32th warehouse, selected products are:
# [49, 42, 47, 8, 40, 20, 14, 33, 6, 27, 29]
#
# For 32th warehouse, selected products' weights are:
# [98.0, 32.0, 123.0, 88.0, 28.0, 110.0, 71.0, 75.0, 14.0, 6.0, 2.0]
#
# For 32th warehouse, selected products' values are:
# [193.54, 59.47, 222.65, 158.56, 50.41, 191.14, 112.04, 110.41, 20.24, 7.35, 1.46]
#
# For 32th warehouse, The Total Weight is: 647.0
# For 32th warehouse, The Total Value is: 1127.27
# For 33th warehouse, selected products are:
# [19, 23, 37, 22, 10, 24, 39, 31, 15, 12]
#
# For 33th warehouse, selected products' weights are:
# [45.0, 108.0, 63.0, 71.0, 19.0, 81.0, 91.0, 68.0, 99.0, 1.0]
#
# For 33th warehouse, selected products' values are:
# [109.16, 223.21, 129.43, 126.89, 33.71, 142.73, 159.8, 116.71, 163.57, 0.7]
#
# For 33th warehouse, The Total Weight is: 646.0
# For 33th warehouse, The Total Value is: 1205.91
# For 34th warehouse, selected products are:
# [18, 3, 20, 13, 11, 48, 12, 22, 7, 16, 36, 30, 49, 46, 9, 14]
#
# For 34th warehouse, selected products' weights are:
# [45.0, 49.0, 12.0, 56.0, 49.0, 82.0, 10.0, 105.0, 95.0, 38.0, 61.0, 24.0, 3.0, 7.0, 4.0, 7.0]
#
# For 34th warehouse, selected products' values are:
# [109.52, 82.15, 19.89, 92.6, 73.26, 122.27, 14.87, 153.86, 137.81, 52.08, 82.26, 30.62, 3.41, 7.78, 4.18, 6.56]
#
# For 34th warehouse, The Total Weight is: 647.0
# For 34th warehouse, The Total Value is: 993.1199999999999
# For 35th warehouse, selected products are:
# [48, 45, 11, 8, 22, 21, 34, 40, 16, 32, 0, 49, 25]
#
# For 35th warehouse, selected products' weights are:
# [89.0, 124.0, 89.0, 51.0, 8.0, 97.0, 38.0, 64.0, 13.0, 17.0, 36.0, 10.0, 3.0]
#
# For 35th warehouse, selected products' values are:
# [171.55, 225.95, 154.89, 87.6, 13.48, 154.19, 60.3, 99.43, 19.15, 24.8, 51.63, 12.83, 3.14]
#
# For 35th warehouse, The Total Weight is: 639.0
# For 35th warehouse, The Total Value is: 1078.94
# For 36th warehouse, selected products are:
# [26, 8, 39, 44, 46, 27, 6, 10, 13, 41, 21, 35, 3, 25]
#
# For 36th warehouse, selected products' weights are:
# [2.0, 94.0, 56.0, 43.0, 87.0, 16.0, 121.0, 51.0, 99.0, 44.0, 6.0, 17.0, 10.0, 4.0]
#
# For 36th warehouse, selected products' values are:
# [4.29, 180.31, 105.36, 74.45, 137.76, 25.14, 180.68, 74.0, 142.38, 60.69, 7.92, 20.27, 11.73, 4.06]
#
# For 36th warehouse, The Total Weight is: 650.0
# For 36th warehouse, The Total Value is: 1029.0399999999997
# For 37th warehouse, selected products are:
# [45, 49, 21, 31, 32, 15, 8, 41, 38, 13]
#
# For 37th warehouse, selected products' weights are:
# [108.0, 111.0, 4.0, 124.0, 59.0, 42.0, 97.0, 45.0, 21.0, 30.0]
#
# For 37th warehouse, selected products' values are:
# [266.7, 240.72, 7.52, 219.27, 101.69, 71.99, 166.13, 71.67, 32.45, 42.98]
#
# For 37th warehouse, The Total Weight is: 641.0
# For 37th warehouse, The Total Value is: 1221.1200000000001
# For 38th warehouse, selected products are:
# [40, 49, 43, 22, 29, 17, 35, 26, 25, 6, 39, 0]
#
# For 38th warehouse, selected products' weights are:
# [122.0, 65.0, 39.0, 77.0, 46.0, 50.0, 107.0, 99.0, 5.0, 29.0, 5.0, 5.0]
#
# For 38th warehouse, selected products' values are:
# [263.8, 120.53, 65.33, 126.99, 75.14, 78.72, 167.28, 146.36, 7.36, 39.63, 4.85, 3.68]
#
# For 38th warehouse, The Total Weight is: 649.0
# For 38th warehouse, The Total Value is: 1099.67
# For 39th warehouse, selected products are:
# [7, 11, 48, 25, 16, 38, 3, 18, 15, 10, 9, 32, 13]
#
# For 39th warehouse, selected products' weights are:
# [112.0, 82.0, 99.0, 66.0, 124.0, 32.0, 62.0, 24.0, 6.0, 27.0, 9.0, 2.0, 2.0]
#
# For 39th warehouse, selected products' values are:
# [239.57, 146.63, 168.95, 109.33, 202.45, 51.91, 98.66, 38.08, 9.21, 37.27, 9.32, 1.48, 1.4]
#
# For 39th warehouse, The Total Weight is: 647.0
# For 39th warehouse, The Total Value is: 1114.26
# For 40th warehouse, selected products are:
# [15, 33, 5, 9, 4, 1, 40, 48, 21, 39, 6]
#
# For 40th warehouse, selected products' weights are:
# [58.0, 16.0, 123.0, 73.0, 56.0, 117.0, 82.0, 52.0, 52.0, 16.0, 5.0]
#
# For 40th warehouse, selected products' values are:
# [121.05, 32.18, 240.81, 133.23, 100.97, 199.57, 129.46, 81.31, 80.38, 19.9, 5.23]
#
# For 40th warehouse, The Total Weight is: 650.0
# For 40th warehouse, The Total Value is: 1144.0900000000001
# For 41th warehouse, selected products are:
# [7, 39, 34, 38, 46, 17, 22, 29, 49, 2, 42, 45]
#
# For 41th warehouse, selected products' weights are:
# [101.0, 23.0, 104.0, 19.0, 4.0, 95.0, 70.0, 33.0, 106.0, 93.0, 1.0, 1.0]
#
# For 41th warehouse, selected products' values are:
# [200.81, 39.72, 178.01, 29.67, 6.24, 139.18, 97.17, 45.31, 144.03, 125.43, 1.07, 0.79]
#
# For 41th warehouse, The Total Weight is: 650.0
# For 41th warehouse, The Total Value is: 1007.43
# For 42th warehouse, selected products are:
# [49, 37, 20, 1, 8, 0, 5, 12, 15, 41, 17]
#
# For 42th warehouse, selected products' weights are:
# [69.0, 117.0, 85.0, 84.0, 32.0, 26.0, 88.0, 1.0, 121.0, 18.0, 8.0]
#
# For 42th warehouse, selected products' values are:
# [127.33, 205.18, 149.06, 136.51, 51.35, 41.55, 135.84, 1.46, 175.06, 23.96, 10.27]
#
# For 42th warehouse, The Total Weight is: 649.0
# For 42th warehouse, The Total Value is: 1057.57
# For 43th warehouse, selected products are:
# [40, 23, 1, 18, 26, 5, 17, 19, 25, 9]
#
# For 43th warehouse, selected products' weights are:
# [99.0, 118.0, 77.0, 15.0, 76.0, 95.0, 118.0, 44.0, 1.0, 7.0]
#
# For 43th warehouse, selected products' values are:
# [193.43, 228.69, 145.69, 26.88, 133.61, 161.09, 200.03, 60.73, 1.33, 7.25]
#
# For 43th warehouse, The Total Weight is: 650.0
# For 43th warehouse, The Total Value is: 1158.73
# For 44th warehouse, selected products are:
# [21, 1, 45, 18, 17, 16, 47, 8, 14, 34]
#
# For 44th warehouse, selected products' weights are:
# [54.0, 34.0, 81.0, 78.0, 87.0, 105.0, 9.0, 116.0, 80.0, 3.0]
#
# For 44th warehouse, selected products' values are:
# [117.31, 66.35, 157.32, 139.54, 140.52, 157.38, 13.25, 169.69, 114.65, 3.42]
#
# For 44th warehouse, The Total Weight is: 647.0
# For 44th warehouse, The Total Value is: 1079.43
# For 45th warehouse, selected products are:
# [42, 34, 28, 45, 7, 29, 24, 43, 41, 23, 0, 2]
#
# For 45th warehouse, selected products' weights are:
# [81.0, 86.0, 98.0, 22.0, 98.0, 12.0, 4.0, 97.0, 50.0, 88.0, 8.0, 3.0]
#
# For 45th warehouse, selected products' values are:
# [165.99, 164.18, 180.16, 39.19, 169.51, 19.84, 6.6, 153.57, 78.87, 130.9, 9.92, 1.9]
#
# For 45th warehouse, The Total Weight is: 647.0
# For 45th warehouse, The Total Value is: 1120.63
# For 46th warehouse, selected products are:
# [36, 30, 38, 43, 22, 42, 23, 4, 24, 3, 12]
#
# For 46th warehouse, selected products' weights are:
# [108.0, 81.0, 67.0, 44.0, 27.0, 75.0, 84.0, 60.0, 78.0, 12.0, 13.0]
#
# For 46th warehouse, selected products' values are:
# [270.71, 162.57, 130.52, 79.43, 44.32, 119.09, 133.06, 94.96, 112.68, 16.91, 17.79]
#
# For 46th warehouse, The Total Weight is: 649.0
# For 46th warehouse, The Total Value is: 1182.0400000000002
# For 47th warehouse, selected products are:
# [15, 21, 44, 1, 41, 45, 47, 16, 6, 11, 31, 5]
#
# For 47th warehouse, selected products' weights are:
# [65.0, 96.0, 10.0, 90.0, 44.0, 95.0, 44.0, 38.0, 107.0, 39.0, 6.0, 16.0]
#
# For 47th warehouse, selected products' values are:
# [125.15, 173.41, 17.92, 159.74, 72.58, 146.98, 67.05, 57.47, 160.22, 56.15, 7.17, 15.41]
#
# For 47th warehouse, The Total Weight is: 650.0
# For 47th warehouse, The Total Value is: 1059.2500000000002
# For 48th warehouse, selected products are:
# [47, 26, 41, 40, 8, 9, 42, 43, 31, 28, 19, 4, 39]
#
# For 48th warehouse, selected products' weights are:
# [90.0, 27.0, 113.0, 99.0, 93.0, 51.0, 77.0, 26.0, 18.0, 44.0, 2.0, 9.0, 1.0]
#
# For 48th warehouse, selected products' values are:
# [169.3, 48.77, 198.55, 171.81, 156.43, 84.55, 123.27, 39.1, 24.58, 58.63, 2.65, 7.21, 0.34]
#
# For 48th warehouse, The Total Weight is: 650.0
# For 48th warehouse, The Total Value is: 1085.1900000000003
# For 49th warehouse, selected products are:
# [40, 36, 47, 12, 37, 41, 35, 27, 22, 30]
#
# For 49th warehouse, selected products' weights are:
# [111.0, 84.0, 107.0, 117.0, 55.0, 109.0, 35.0, 2.0, 4.0, 17.0]
#
# For 49th warehouse, selected products' values are:
# [259.78, 141.26, 173.26, 188.34, 87.57, 169.1, 49.91, 2.68, 4.5, 12.49]
#
# For 49th warehouse, The Total Weight is: 641.0
# For 49th warehouse, The Total Value is: 1088.89
# For 50th warehouse, selected products are:
# [48, 15, 10, 4, 45, 32, 47, 17, 18, 8, 34]
#
# For 50th warehouse, selected products' weights are:
# [9.0, 112.0, 104.0, 111.0, 33.0, 40.0, 103.0, 16.0, 99.0, 13.0, 10.0]
#
# For 50th warehouse, selected products' values are:
# [16.72, 205.4, 184.08, 196.06, 56.16, 66.68, 148.87, 22.47, 136.55, 15.11, 8.94]
#
# For 50th warehouse, The Total Weight is: 650.0
# For 50th warehouse, The Total Value is: 1057.04
# For 51th warehouse, selected products are:
# [36, 17, 12, 1, 48, 40, 39, 16, 3, 43]
#
# For 51th warehouse, selected products' weights are:
# [123.0, 117.0, 6.0, 95.0, 124.0, 60.0, 38.0, 29.0, 44.0, 14.0]
#
# For 51th warehouse, selected products' values are:
# [326.11, 240.74, 11.29, 174.0, 215.55, 93.02, 54.91, 40.44, 55.02, 14.79]
#
# For 51th warehouse, The Total Weight is: 650.0
# For 51th warehouse, The Total Value is: 1225.8700000000001
# For 52th warehouse, selected products are:
# [33, 21, 9, 12, 31, 5, 1, 41, 15, 10, 38, 3, 43, 26, 47, 37]
#
# For 52th warehouse, selected products' weights are:
# [8.0, 2.0, 1.0, 59.0, 55.0, 30.0, 73.0, 25.0, 58.0, 15.0, 115.0, 113.0, 73.0, 11.0, 2.0, 6.0]
#
# For 52th warehouse, selected products' values are:
# [18.18, 4.17, 1.8, 103.09, 92.33, 47.14, 111.1, 37.79, 80.52, 20.2, 151.54, 139.98, 89.97, 13.4, 1.38, 3.03]
#
# For 52th warehouse, The Total Weight is: 646.0
# For 52th warehouse, The Total Value is: 915.6199999999999
# For 53th warehouse, selected products are:
# [2, 6, 12, 38, 16, 7, 4, 37, 15, 21, 43, 13]
#
# For 53th warehouse, selected products' weights are:
# [64.0, 98.0, 33.0, 7.0, 66.0, 8.0, 120.0, 38.0, 83.0, 65.0, 54.0, 5.0]
#
# For 53th warehouse, selected products' values are:
# [129.65, 185.95, 58.22, 11.85, 101.52, 11.9, 174.83, 54.83, 119.27, 89.56, 72.58, 1.12]
#
# For 53th warehouse, The Total Weight is: 641.0
# For 53th warehouse, The Total Value is: 1011.2800000000002
# For 54th warehouse, selected products are:
# [43, 13, 28, 12, 31, 34, 38, 10, 9, 45, 24, 47, 30, 21]
#
# For 54th warehouse, selected products' weights are:
# [114.0, 61.0, 11.0, 13.0, 105.0, 72.0, 86.0, 108.0, 48.0, 25.0, 1.0, 1.0, 2.0, 3.0]
#
# For 54th warehouse, selected products' values are:
# [224.63, 111.65, 19.39, 21.29, 156.59, 107.29, 128.1, 159.78, 70.29, 35.74, 1.3, 0.85, 1.45, 1.49]
#
# For 54th warehouse, The Total Weight is: 650.0
# For 54th warehouse, The Total Value is: 1039.8399999999997
# For 55th warehouse, selected products are:
# [5, 23, 29, 15, 6, 9, 28, 36, 44, 32, 26, 43]
#
# For 55th warehouse, selected products' weights are:
# [96.0, 125.0, 17.0, 105.0, 36.0, 84.0, 2.0, 45.0, 81.0, 23.0, 20.0, 15.0]
#
# For 55th warehouse, selected products' values are:
# [188.67, 242.6, 30.84, 183.12, 62.71, 139.15, 3.26, 73.33, 130.31, 34.4, 26.37, 15.81]
#
# For 55th warehouse, The Total Weight is: 649.0
# For 55th warehouse, The Total Value is: 1130.57
# For 56th warehouse, selected products are:
# [7, 28, 36, 42, 13, 27, 10, 5, 33, 39, 1]
#
# For 56th warehouse, selected products' weights are:
# [4.0, 100.0, 89.0, 112.0, 79.0, 82.0, 5.0, 69.0, 21.0, 82.0, 5.0]
#
# For 56th warehouse, selected products' values are:
# [7.4, 176.79, 151.94, 188.76, 121.82, 124.73, 7.01, 96.54, 27.96, 106.35, 4.28]
#
# For 56th warehouse, The Total Weight is: 648.0
# For 56th warehouse, The Total Value is: 1013.58
# For 57th warehouse, selected products are:
# [43, 17, 35, 24, 48, 11, 26, 37, 49, 47, 9]
#
# For 57th warehouse, selected products' weights are:
# [95.0, 55.0, 104.0, 8.0, 125.0, 85.0, 63.0, 41.0, 11.0, 54.0, 9.0]
#
# For 57th warehouse, selected products' values are:
# [188.49, 105.61, 192.77, 14.13, 211.39, 131.69, 97.11, 56.93, 14.43, 67.16, 8.65]
#
# For 57th warehouse, The Total Weight is: 650.0
# For 57th warehouse, The Total Value is: 1088.36
# For 58th warehouse, selected products are:
# [20, 27, 28, 31, 45, 10, 33, 42, 3, 41, 8, 29, 11, 36, 34, 7]
#
# For 58th warehouse, selected products' weights are:
# [44.0, 44.0, 18.0, 46.0, 120.0, 22.0, 47.0, 101.0, 10.0, 45.0, 23.0, 61.0, 20.0, 30.0, 11.0, 4.0]
#
# For 58th warehouse, selected products' values are:
# [104.64, 89.17, 35.63, 87.34, 213.88, 38.22, 79.04, 158.81, 15.52, 66.78, 33.85, 87.33, 28.44, 41.08, 14.19, 2.01]
#
# For 58th warehouse, The Total Weight is: 646.0
# For 58th warehouse, The Total Value is: 1095.93
# For 59th warehouse, selected products are:
# [20, 31, 24, 43, 32, 10, 47, 34, 41, 45, 35]
#
# For 59th warehouse, selected products' weights are:
# [65.0, 45.0, 69.0, 44.0, 83.0, 51.0, 75.0, 51.0, 69.0, 25.0, 59.0]
#
# For 59th warehouse, selected products' values are:
# [150.01, 90.77, 122.05, 75.57, 141.71, 86.37, 124.63, 76.72, 97.27, 35.24, 77.95]
#
# For 59th warehouse, The Total Weight is: 636.0
# For 59th warehouse, The Total Value is: 1078.29
# For 60th warehouse, selected products are:
# [45, 19, 40, 48, 30, 7, 28, 13, 17, 34, 14, 47]
#
# For 60th warehouse, selected products' weights are:
# [120.0, 13.0, 36.0, 92.0, 59.0, 96.0, 11.0, 77.0, 21.0, 73.0, 4.0, 44.0]
#
# For 60th warehouse, selected products' values are:
# [274.36, 27.55, 66.28, 143.21, 90.28, 144.07, 16.05, 108.42, 29.37, 97.44, 5.31, 55.73]
#
# For 60th warehouse, The Total Weight is: 646.0
# For 60th warehouse, The Total Value is: 1058.07
# For 61th warehouse, selected products are:
# [33, 46, 12, 13, 1, 42, 49, 36, 35, 10, 39, 37, 18, 0]
#
# For 61th warehouse, selected products' weights are:
# [54.0, 70.0, 90.0, 51.0, 65.0, 93.0, 54.0, 37.0, 2.0, 16.0, 35.0, 67.0, 8.0, 8.0]
#
# For 61th warehouse, selected products' values are:
# [102.45, 130.45, 153.67, 86.5, 106.9, 152.54, 87.44, 59.22, 3.09, 22.3, 47.53, 88.45, 10.42, 10.15]
#
# For 61th warehouse, The Total Weight is: 650.0
# For 61th warehouse, The Total Value is: 1061.11
# For 62th warehouse, selected products are:
# [11, 25, 6, 34, 14, 16, 39, 5, 2, 49, 28, 4, 19, 40]
#
# For 62th warehouse, selected products' weights are:
# [31.0, 29.0, 107.0, 49.0, 37.0, 60.0, 15.0, 53.0, 97.0, 27.0, 60.0, 77.0, 5.0, 1.0]
#
# For 62th warehouse, selected products' values are:
# [63.77, 59.05, 199.46, 83.98, 62.25, 92.0, 22.55, 79.08, 141.27, 39.12, 83.22, 103.06, 4.62, 0.92]
#
# For 62th warehouse, The Total Weight is: 648.0
# For 62th warehouse, The Total Value is: 1034.35
# For 63th warehouse, selected products are:
# [21, 20, 13, 43, 2, 39, 47, 10, 16, 8, 30, 44, 25]
#
# For 63th warehouse, selected products' weights are:
# [2.0, 51.0, 57.0, 86.0, 67.0, 110.0, 19.0, 103.0, 7.0, 82.0, 6.0, 57.0, 1.0]
#
# For 63th warehouse, selected products' values are:
# [4.67, 110.99, 122.41, 173.49, 131.18, 200.19, 33.91, 175.59, 11.45, 129.91, 8.67, 77.51, 0.51]
#
# For 63th warehouse, The Total Weight is: 648.0
# For 63th warehouse, The Total Value is: 1180.4800000000002
# For 64th warehouse, selected products are:
# [42, 30, 6, 10, 0, 15, 25, 23, 7, 41, 47, 13, 27, 45, 46, 26, 36]
#
# For 64th warehouse, selected products' weights are:
# [70.0, 56.0, 90.0, 28.0, 26.0, 93.0, 114.0, 23.0, 18.0, 52.0, 26.0, 5.0, 15.0, 16.0, 1.0, 13.0, 3.0]
#
# For 64th warehouse, selected products' values are:
# [165.96, 111.28, 146.55, 41.69, 38.49, 137.21, 160.42, 30.97, 23.16, 66.51, 32.08, 6.16, 17.79, 18.26, 0.74, 4.61, 0.15]
#
# For 64th warehouse, The Total Weight is: 649.0
# For 64th warehouse, The Total Value is: 1002.03
# For 65th warehouse, selected products are:
# [15, 20, 26, 9, 24, 49, 47, 8, 14, 22, 31, 36, 42, 12]
#
# For 65th warehouse, selected products' weights are:
# [7.0, 45.0, 7.0, 111.0, 125.0, 98.0, 100.0, 14.0, 17.0, 85.0, 23.0, 5.0, 2.0, 9.0]
#
# For 65th warehouse, selected products' values are:
# [16.77, 104.97, 13.9, 211.84, 238.26, 184.83, 174.92, 24.27, 29.26, 141.79, 37.59, 7.55, 2.85, 9.13]
#
# For 65th warehouse, The Total Weight is: 648.0
# For 65th warehouse, The Total Value is: 1197.9299999999998
# For 66th warehouse, selected products are:
# [36, 42, 35, 30, 5, 14, 39, 38, 40, 17, 46, 26, 18, 41, 23]
#
# For 66th warehouse, selected products' weights are:
# [51.0, 57.0, 77.0, 37.0, 32.0, 51.0, 17.0, 14.0, 125.0, 122.0, 14.0, 8.0, 29.0, 7.0, 8.0]
#
# For 66th warehouse, selected products' values are:
# [93.58, 99.8, 134.13, 58.78, 49.88, 77.08, 24.85, 20.42, 174.75, 165.56, 18.93, 9.8, 28.41, 6.81, 3.71]
#
# For 66th warehouse, The Total Weight is: 649.0
# For 66th warehouse, The Total Value is: 966.4899999999998
# For 67th warehouse, selected products are:
# [18, 43, 45, 25, 24, 23, 6, 13, 8, 4, 26, 19, 9, 21, 16]
#
# For 67th warehouse, selected products' weights are:
# [58.0, 66.0, 62.0, 79.0, 47.0, 102.0, 12.0, 24.0, 43.0, 72.0, 21.0, 47.0, 13.0, 2.0, 1.0]
#
# For 67th warehouse, selected products' values are:
# [103.73, 108.56, 98.81, 124.27, 71.39, 152.2, 17.82, 35.28, 63.18, 105.0, 29.22, 60.81, 13.05, 1.87, 0.88]
#
# For 67th warehouse, The Total Weight is: 649.0
# For 67th warehouse, The Total Value is: 986.0699999999999
# For 68th warehouse, selected products are:
# [33, 47, 0, 28, 46, 41, 7, 21, 3, 6, 15, 20]
#
# For 68th warehouse, selected products' weights are:
# [14.0, 123.0, 122.0, 80.0, 87.0, 14.0, 38.0, 119.0, 11.0, 22.0, 10.0, 8.0]
#
# For 68th warehouse, selected products' values are:
# [31.75, 259.76, 244.19, 147.88, 144.74, 22.89, 60.89, 185.28, 16.87, 32.9, 12.16, 9.19]
#
# For 68th warehouse, The Total Weight is: 648.0
# For 68th warehouse, The Total Value is: 1168.5000000000002
# For 69th warehouse, selected products are:
# [7, 34, 36, 13, 43, 31, 3, 48, 35, 27, 47, 9, 5]
#
# For 69th warehouse, selected products' weights are:
# [57.0, 76.0, 71.0, 35.0, 84.0, 19.0, 26.0, 79.0, 77.0, 109.0, 1.0, 3.0, 5.0]
#
# For 69th warehouse, selected products' values are:
# [127.32, 136.92, 126.57, 61.01, 144.18, 31.37, 41.01, 124.32, 119.11, 153.1, 1.37, 3.0, 4.01]
#
# For 69th warehouse, The Total Weight is: 642.0
# For 69th warehouse, The Total Value is: 1073.29
# For 70th warehouse, selected products are:
# [31, 8, 37, 22, 29, 49, 3, 6, 40, 19, 25, 33, 38, 12]
#
# For 70th warehouse, selected products' weights are:
# [17.0, 106.0, 35.0, 86.0, 113.0, 80.0, 9.0, 5.0, 82.0, 49.0, 34.0, 20.0, 12.0, 1.0]
#
# For 70th warehouse, selected products' values are:
# [43.01, 208.31, 67.77, 164.4, 207.96, 143.51, 14.49, 7.96, 126.88, 73.26, 44.27, 21.15, 12.12, 0.74]
#
# For 70th warehouse, The Total Weight is: 649.0
# For 70th warehouse, The Total Value is: 1135.8300000000002
# For 71th warehouse, selected products are:
# [31, 20, 39, 9, 44, 7, 24, 33, 27]
#
# For 71th warehouse, selected products' weights are:
# [48.0, 68.0, 38.0, 49.0, 44.0, 76.0, 120.0, 95.0, 100.0]
#
# For 71th warehouse, selected products' values are:
# [107.71, 143.91, 66.23, 79.66, 68.69, 115.73, 162.27, 126.93, 129.81]
#
# For 71th warehouse, The Total Weight is: 638.0
# For 71th warehouse, The Total Value is: 1000.9399999999998
# For 72th warehouse, selected products are:
# [26, 35, 44, 5, 3, 14, 9, 45, 13, 20, 30, 10]
#
# For 72th warehouse, selected products' weights are:
# [104.0, 66.0, 34.0, 47.0, 53.0, 93.0, 78.0, 113.0, 24.0, 19.0, 18.0, 1.0]
#
# For 72th warehouse, selected products' values are:
# [206.52, 112.29, 57.53, 78.05, 86.97, 150.8, 126.27, 168.29, 32.25, 25.09, 16.6, 0.83]
#
# For 72th warehouse, The Total Weight is: 650.0
# For 72th warehouse, The Total Value is: 1061.4899999999998
# For 73th warehouse, selected products are:
# [48, 6, 46, 28, 3, 2, 38, 8, 35, 43]
#
# For 73th warehouse, selected products' weights are:
# [69.0, 94.0, 110.0, 97.0, 116.0, 120.0, 16.0, 8.0, 11.0, 9.0]
#
# For 73th warehouse, selected products' values are:
# [170.17, 208.82, 201.72, 176.19, 192.31, 197.13, 25.09, 11.12, 14.44, 11.65]
#
# For 73th warehouse, The Total Weight is: 650.0
# For 73th warehouse, The Total Value is: 1208.64
# For 74th warehouse, selected products are:
# [33, 26, 38, 28, 47, 14, 27, 30, 22, 20, 24, 15]
#
# For 74th warehouse, selected products' weights are:
# [98.0, 86.0, 43.0, 17.0, 93.0, 71.0, 71.0, 64.0, 77.0, 13.0, 8.0, 9.0]
#
# For 74th warehouse, selected products' values are:
# [211.2, 169.94, 79.33, 30.63, 164.04, 123.16, 121.77, 107.31, 126.31, 20.24, 11.21, 10.65]
#
# For 74th warehouse, The Total Weight is: 650.0
# For 74th warehouse, The Total Value is: 1175.79
# For 75th warehouse, selected products are:
# [10, 38, 26, 33, 29, 1, 46, 44, 37, 15, 13, 43, 42]
#
# For 75th warehouse, selected products' weights are:
# [4.0, 28.0, 53.0, 79.0, 43.0, 97.0, 28.0, 85.0, 65.0, 59.0, 59.0, 2.0, 47.0]
#
# For 75th warehouse, selected products' values are:
# [8.26, 52.68, 96.5, 131.94, 69.71, 151.44, 43.09, 122.7, 93.64, 84.65, 84.14, 2.56, 59.28]
#
# For 75th warehouse, The Total Weight is: 649.0
# For 75th warehouse, The Total Value is: 1000.5899999999999
# For 76th warehouse, selected products are:
# [43, 2, 3, 31, 44, 22, 48, 28, 15, 12, 27, 13, 14]
#
# For 76th warehouse, selected products' weights are:
# [13.0, 24.0, 79.0, 100.0, 22.0, 122.0, 10.0, 26.0, 113.0, 68.0, 31.0, 5.0, 34.0]
#
# For 76th warehouse, selected products' values are:
# [26.12, 46.85, 135.51, 167.77, 35.43, 181.5, 14.86, 38.39, 160.11, 94.79, 41.33, 6.62, 39.13]
#
# For 76th warehouse, The Total Weight is: 647.0
# For 76th warehouse, The Total Value is: 988.4100000000001
# For 77th warehouse, selected products are:
# [16, 14, 5, 10, 7, 27, 15, 30, 20, 33, 40, 19, 3, 29, 2, 1, 8]
#
# For 77th warehouse, selected products' weights are:
# [38.0, 64.0, 34.0, 5.0, 66.0, 61.0, 3.0, 36.0, 51.0, 42.0, 51.0, 67.0, 115.0, 4.0, 2.0, 3.0, 5.0]
#
# For 77th warehouse, selected products' values are:
# [69.91, 112.13, 58.92, 8.52, 112.2, 102.88, 5.04, 59.87, 80.33, 65.34, 79.14, 98.85, 166.11, 5.1, 2.15, 1.64, 2.13]
#
# For 77th warehouse, The Total Weight is: 647.0
# For 77th warehouse, The Total Value is: 1030.2600000000004
# For 78th warehouse, selected products are:
# [19, 35, 40, 15, 33, 42, 38, 2, 21, 7, 49, 23, 32, 26, 4]
#
# For 78th warehouse, selected products' weights are:
# [86.0, 28.0, 59.0, 23.0, 44.0, 64.0, 88.0, 38.0, 96.0, 85.0, 7.0, 21.0, 5.0, 2.0, 1.0]
#
# For 78th warehouse, selected products' values are:
# [164.29, 51.61, 101.08, 36.53, 66.16, 90.27, 122.7, 51.82, 130.34, 115.24, 9.48, 28.43, 4.8, 1.69, 0.1]
#
# For 78th warehouse, The Total Weight is: 647.0
# For 78th warehouse, The Total Value is: 974.5400000000001
# For 79th warehouse, selected products are:
# [5, 42, 35, 33, 48, 45, 37, 18, 26, 2, 13, 10, 47, 49, 6]
#
# For 79th warehouse, selected products' weights are:
# [11.0, 23.0, 25.0, 34.0, 58.0, 15.0, 86.0, 35.0, 3.0, 91.0, 79.0, 54.0, 71.0, 28.0, 37.0]
#
# For 79th warehouse, selected products' values are:
# [21.13, 41.56, 44.0, 56.77, 96.64, 24.93, 137.24, 55.21, 4.43, 132.11, 112.64, 74.67, 96.64, 36.94, 48.75]
#
# For 79th warehouse, The Total Weight is: 650.0
# For 79th warehouse, The Total Value is: 983.6599999999999
# For 80th warehouse, selected products are:
# [24, 3, 46, 43, 41, 35, 5, 14, 36, 29, 16, 47, 25]
#
# For 80th warehouse, selected products' weights are:
# [73.0, 101.0, 87.0, 40.0, 86.0, 116.0, 19.0, 83.0, 11.0, 11.0, 10.0, 9.0, 1.0]
#
# For 80th warehouse, selected products' values are:
# [161.94, 206.22, 160.69, 67.38, 138.79, 175.82, 28.68, 123.22, 15.21, 15.14, 13.05, 10.89, 0.82]
#
# For 80th warehouse, The Total Weight is: 647.0
# For 80th warehouse, The Total Value is: 1117.85
# For 81th warehouse, selected products are:
# [1, 17, 19, 4, 46, 10, 31, 13, 15, 35, 23, 30]
#
# For 81th warehouse, selected products' weights are:
# [115.0, 49.0, 96.0, 44.0, 45.0, 95.0, 59.0, 84.0, 40.0, 6.0, 1.0, 10.0]
#
# For 81th warehouse, selected products' values are:
# [228.51, 94.21, 158.91, 70.58, 69.46, 138.24, 83.55, 117.24, 55.77, 6.09, 0.97, 7.0]
#
# For 81th warehouse, The Total Weight is: 644.0
# For 81th warehouse, The Total Value is: 1030.5300000000002
# For 82th warehouse, selected products are:
# [29, 43, 49, 4, 28, 46, 30, 38, 6, 8]
#
# For 82th warehouse, selected products' weights are:
# [20.0, 105.0, 50.0, 81.0, 90.0, 109.0, 23.0, 51.0, 105.0, 16.0]
#
# For 82th warehouse, selected products' values are:
# [42.23, 188.13, 88.92, 141.95, 156.28, 188.93, 35.94, 78.55, 155.92, 23.01]
#
# For 82th warehouse, The Total Weight is: 650.0
# For 82th warehouse, The Total Value is: 1099.8600000000001
# For 83th warehouse, selected products are:
# [45, 1, 20, 14, 32, 6, 29, 24, 34, 49, 47, 18, 19, 2, 3, 23, 44, 10]
#
# For 83th warehouse, selected products' weights are:
# [15.0, 25.0, 44.0, 39.0, 83.0, 5.0, 8.0, 51.0, 33.0, 12.0, 7.0, 97.0, 91.0, 21.0, 48.0, 22.0, 30.0, 18.0]
#
# For 83th warehouse, selected products' values are:
# [34.72, 52.27, 85.09, 66.07, 137.53, 8.19, 12.98, 81.75, 47.04, 16.96, 9.87, 134.37, 121.19, 27.13, 61.27, 26.99, 35.75, 15.07]
#
# For 83th warehouse, The Total Weight is: 649.0
# For 83th warehouse, The Total Value is: 974.24
# For 84th warehouse, selected products are:
# [16, 39, 43, 28, 34, 0, 17, 36, 29, 8, 49, 48]
#
# For 84th warehouse, selected products' weights are:
# [15.0, 56.0, 93.0, 39.0, 52.0, 12.0, 96.0, 81.0, 49.0, 55.0, 55.0, 45.0]
#
# For 84th warehouse, selected products' values are:
# [30.76, 114.25, 178.29, 73.37, 97.33, 21.87, 170.65, 138.02, 79.09, 83.64, 82.54, 61.63]
#
# For 84th warehouse, The Total Weight is: 648.0
# For 84th warehouse, The Total Value is: 1131.44
# For 85th warehouse, selected products are:
# [12, 24, 19, 21, 36, 44, 28, 33, 16, 47, 22, 35, 10, 45]
#
# For 85th warehouse, selected products' weights are:
# [19.0, 4.0, 81.0, 39.0, 102.0, 33.0, 121.0, 43.0, 118.0, 13.0, 18.0, 35.0, 6.0, 9.0]
#
# For 85th warehouse, selected products' values are:
# [42.54, 8.74, 155.57, 73.87, 190.16, 59.49, 214.43, 75.7, 194.75, 17.76, 24.45, 46.94, 7.37, 10.85]
#
# For 85th warehouse, The Total Weight is: 641.0
# For 85th warehouse, The Total Value is: 1122.62
# For 86th warehouse, selected products are:
# [41, 7, 6, 24, 11, 29, 38, 5, 15, 32]
#
# For 86th warehouse, selected products' weights are:
# [119.0, 55.0, 42.0, 9.0, 102.0, 34.0, 87.0, 74.0, 82.0, 46.0]
#
# For 86th warehouse, selected products' values are:
# [233.68, 104.2, 78.31, 16.63, 162.92, 54.3, 138.16, 111.62, 123.12, 63.08]
#
# For 86th warehouse, The Total Weight is: 650.0
# For 86th warehouse, The Total Value is: 1086.02
# For 87th warehouse, selected products are:
# [2, 23, 11, 6, 40, 22, 36, 46, 43, 49, 37]
#
# For 87th warehouse, selected products' weights are:
# [108.0, 28.0, 76.0, 55.0, 120.0, 94.0, 49.0, 100.0, 13.0, 3.0, 4.0]
#
# For 87th warehouse, selected products' values are:
# [222.81, 52.31, 139.15, 94.7, 199.03, 154.5, 77.39, 147.19, 17.62, 3.01, 3.11]
#
# For 87th warehouse, The Total Weight is: 650.0
# For 87th warehouse, The Total Value is: 1110.8199999999997
# For 88th warehouse, selected products are:
# [33, 36, 28, 44, 45, 31, 15, 9, 29, 27, 48, 39]
#
# For 88th warehouse, selected products' weights are:
# [33.0, 20.0, 41.0, 56.0, 108.0, 99.0, 111.0, 5.0, 51.0, 81.0, 9.0, 34.0]
#
# For 88th warehouse, selected products' values are:
# [60.95, 36.49, 72.88, 96.22, 182.08, 160.8, 177.29, 7.57, 68.21, 106.09, 11.45, 42.24]
#
# For 88th warehouse, The Total Weight is: 648.0
# For 88th warehouse, The Total Value is: 1022.2700000000002
# For 89th warehouse, selected products are:
# [21, 31, 35, 33, 43, 30, 40, 0, 8, 32]
#
# For 89th warehouse, selected products' weights are:
# [54.0, 119.0, 91.0, 68.0, 117.0, 80.0, 91.0, 12.0, 15.0, 2.0]
#
# For 89th warehouse, selected products' values are:
# [108.17, 196.35, 149.74, 109.72, 186.99, 124.85, 140.75, 17.1, 19.81, 1.48]
#
# For 89th warehouse, The Total Weight is: 649.0
# For 89th warehouse, The Total Value is: 1054.96
# For 90th warehouse, selected products are:
# [47, 3, 39, 42, 11, 5, 31, 13, 44, 37, 23, 45, 0, 46, 21]
#
# For 90th warehouse, selected products' weights are:
# [76.0, 13.0, 42.0, 24.0, 96.0, 85.0, 36.0, 57.0, 44.0, 6.0, 43.0, 26.0, 8.0, 81.0, 10.0]
#
# For 90th warehouse, selected products' values are:
# [157.23, 26.65, 68.74, 38.54, 149.61, 117.22, 49.24, 77.38, 59.3, 7.21, 51.01, 30.22, 8.98, 89.14, 10.55]
#
# For 90th warehouse, The Total Weight is: 647.0
# For 90th warehouse, The Total Value is: 941.02
# For 91th warehouse, selected products are:
# [5, 15, 48, 26, 12, 42, 28, 38, 19, 40, 36, 35]
#
# For 91th warehouse, selected products' weights are:
# [62.0, 10.0, 104.0, 121.0, 27.0, 78.0, 13.0, 71.0, 14.0, 98.0, 48.0, 4.0]
#
# For 91th warehouse, selected products' values are:
# [149.07, 19.91, 204.2, 229.47, 48.42, 139.2, 23.02, 120.18, 22.11, 154.3, 74.0, 2.77]
#
# For 91th warehouse, The Total Weight is: 650.0
# For 91th warehouse, The Total Value is: 1186.65
# For 92th warehouse, selected products are:
# [4, 42, 45, 6, 31, 32, 36, 2, 5, 17, 20, 49]
#
# For 92th warehouse, selected products' weights are:
# [125.0, 117.0, 122.0, 41.0, 52.0, 52.0, 77.0, 48.0, 12.0, 1.0, 1.0, 2.0]
#
# For 92th warehouse, selected products' values are:
# [220.28, 194.87, 203.11, 65.52, 79.39, 79.15, 116.91, 71.15, 15.8, 0.73, 0.68, 1.35]
#
# For 92th warehouse, The Total Weight is: 650.0
# For 92th warehouse, The Total Value is: 1048.9399999999998
# For 93th warehouse, selected products are:
# [2, 3, 44, 8, 41, 42, 29, 35, 38, 11, 9, 37, 16, 30, 39, 12]
#
# For 93th warehouse, selected products' weights are:
# [84.0, 57.0, 12.0, 114.0, 85.0, 16.0, 12.0, 48.0, 35.0, 44.0, 80.0, 29.0, 8.0, 18.0, 4.0, 3.0]
#
# For 93th warehouse, selected products' values are:
# [151.78, 95.69, 20.01, 189.65, 139.93, 26.07, 18.56, 73.96, 52.17, 64.72, 113.84, 39.71, 8.63, 16.19, 2.42, 1.64]
#
# For 93th warehouse, The Total Weight is: 649.0
# For 93th warehouse, The Total Value is: 1014.97
# For 94th warehouse, selected products are:
# [8, 21, 38, 20, 39, 24, 2, 45, 41, 35, 48]
#
# For 94th warehouse, selected products' weights are:
# [11.0, 2.0, 123.0, 19.0, 41.0, 119.0, 24.0, 85.0, 125.0, 64.0, 36.0]
#
# For 94th warehouse, selected products' values are:
# [25.33, 4.28, 238.8, 33.74, 70.4, 194.86, 38.17, 130.16, 190.45, 93.12, 47.33]
#
# For 94th warehouse, The Total Weight is: 649.0
# For 94th warehouse, The Total Value is: 1066.64
# For 95th warehouse, selected products are:
# [19, 40, 44, 12, 17, 45, 5, 42, 22, 26, 32, 23]
#
# For 95th warehouse, selected products' weights are:
# [23.0, 14.0, 79.0, 118.0, 97.0, 102.0, 84.0, 73.0, 32.0, 13.0, 6.0, 1.0]
#
# For 95th warehouse, selected products' values are:
# [45.58, 26.0, 143.81, 214.76, 165.07, 152.5, 123.13, 105.38, 45.11, 17.12, 7.22, 0.33]
#
# For 95th warehouse, The Total Weight is: 642.0
# For 95th warehouse, The Total Value is: 1046.01
# For 96th warehouse, selected products are:
# [39, 11, 6, 26, 17, 25, 24, 43, 49, 46, 13, 12, 16, 8, 27, 38, 42]
#
# For 96th warehouse, selected products' weights are:
# [16.0, 2.0, 2.0, 124.0, 72.0, 29.0, 83.0, 22.0, 96.0, 28.0, 10.0, 81.0, 34.0, 5.0, 32.0, 12.0, 1.0]
#
# For 96th warehouse, selected products' values are:
# [33.91, 4.05, 3.79, 219.25, 114.74, 45.57, 119.6, 30.16, 131.26, 37.37, 12.4, 98.76, 40.93, 5.39, 32.04, 9.58, 0.5]
#
# For 96th warehouse, The Total Weight is: 649.0
# For 96th warehouse, The Total Value is: 939.2999999999998
# For 97th warehouse, selected products are:
# [3, 2, 25, 18, 48, 1, 19, 34, 47, 0, 5, 13, 41, 40, 23]
#
# For 97th warehouse, selected products' weights are:
# [67.0, 19.0, 30.0, 98.0, 45.0, 1.0, 59.0, 100.0, 52.0, 44.0, 4.0, 90.0, 26.0, 4.0, 4.0]
#
# For 97th warehouse, selected products' values are:
# [139.47, 39.06, 58.67, 175.99, 79.98, 1.52, 80.38, 132.85, 66.87, 55.59, 4.94, 110.71, 31.1, 4.38, 2.79]
#
# For 97th warehouse, The Total Weight is: 643.0
# For 97th warehouse, The Total Value is: 984.3000000000001
# For 98th warehouse, selected products are:
# [5, 46, 19, 28, 25, 23, 22, 13, 4, 20, 39, 10]
#
# For 98th warehouse, selected products' weights are:
# [3.0, 94.0, 55.0, 86.0, 68.0, 22.0, 39.0, 54.0, 29.0, 125.0, 71.0, 4.0]
#
# For 98th warehouse, selected products' values are:
# [5.88, 161.38, 88.85, 135.3, 104.04, 33.18, 56.55, 74.64, 40.01, 171.88, 93.52, 2.93]
#
# For 98th warehouse, The Total Weight is: 650.0
# For 98th warehouse, The Total Value is: 968.1599999999999
# For 99th warehouse, selected products are:
# [21, 10, 46, 18, 27, 48, 0, 28, 1]
#
# For 99th warehouse, selected products' weights are:
# [95.0, 41.0, 66.0, 58.0, 125.0, 125.0, 29.0, 87.0, 22.0]
#
# For 99th warehouse, selected products' values are:
# [222.47, 72.07, 106.52, 92.42, 193.29, 191.66, 43.67, 125.19, 29.56]
#
# For 99th warehouse, The Total Weight is: 648.0
# For 99th warehouse, The Total Value is: 1076.85
# For 100th warehouse, selected products are:
# [26, 37, 7, 44, 19, 25, 29, 21, 3, 39, 16, 45, 17, 36, 40, 47]
#
# For 100th warehouse, selected products' weights are:
# [9.0, 100.0, 67.0, 95.0, 44.0, 2.0, 42.0, 38.0, 18.0, 45.0, 22.0, 57.0, 62.0, 23.0, 18.0, 5.0]
#
# For 100th warehouse, selected products' values are:
# [17.62, 190.21, 116.75, 162.81, 74.36, 3.33, 69.3, 62.61, 29.02, 72.34, 35.22, 89.25, 95.44, 34.4, 24.11, 5.14]
#
# For 100th warehouse, The Total Weight is: 647.0
# For 100th warehouse, The Total Value is: 1081.91
# For 101th warehouse, selected products are:
# ...
#
# For 266th warehouse, selected products' values are:
# [99.53, 157.72, 98.46, 73.07, 48.42, 27.38, 163.0, 85.05, 61.34, 123.11, 76.33, 25.64, 44.16, 0.83]
#
# For 266th warehouse, The Total Weight is: 647.0
# For 266th warehouse, The Total Value is: 1084.04
# For 267th warehouse, selected products are:
# [38, 43, 23, 5, 16, 27, 22, 15, 12, 4, 48]
#
# For 267th warehouse, selected products' weights are:
# [83.0, 125.0, 121.0, 50.0, 48.0, 30.0, 103.0, 66.0, 4.0, 10.0, 10.0]
#
# For 267th warehouse, selected products' values are:
# [193.84, 241.77, 233.06, 91.04, 87.34, 51.27, 151.6, 95.81, 5.6, 9.48, 8.55]
#
# For 267th warehouse, The Total Weight is: 650.0
# For 267th warehouse, The Total Value is: 1169.36
# For 268th warehouse, selected products are:
# [12, 4, 5, 22, 45, 28, 44, 36, 38, 13, 37, 18, 32, 49]
#
# For 268th warehouse, selected products' weights are:
# [88.0, 100.0, 34.0, 27.0, 43.0, 21.0, 113.0, 9.0, 34.0, 95.0, 16.0, 35.0, 25.0, 10.0]
#
# For 268th warehouse, selected products' values are:
# [163.18, 175.57, 59.34, 45.17, 66.64, 31.56, 164.94, 13.11, 47.82, 130.45, 21.6, 45.19, 29.34, 9.01]
#
# For 268th warehouse, The Total Weight is: 650.0
# For 268th warehouse, The Total Value is: 1002.9200000000002
# For 269th warehouse, selected products are:
# [37, 48, 20, 16, 42, 10, 26, 39, 2, 46, 13, 35, 4]
#
# For 269th warehouse, selected products' weights are:
# [72.0, 60.0, 104.0, 66.0, 40.0, 45.0, 11.0, 115.0, 7.0, 117.0, 3.0, 4.0, 6.0]
#
# For 269th warehouse, selected products' values are:
# [122.13, 97.99, 168.8, 103.91, 62.03, 69.24, 16.7, 169.01, 10.17, 169.16, 3.5, 4.16, 5.62]
#
# For 269th warehouse, The Total Weight is: 650.0
# For 269th warehouse, The Total Value is: 1002.42
# For 270th warehouse, selected products are:
# [13, 39, 1, 8, 42, 40, 46, 7, 6, 2, 12]
#
# For 270th warehouse, selected products' weights are:
# [122.0, 30.0, 117.0, 76.0, 76.0, 106.0, 21.0, 80.0, 12.0, 7.0, 2.0]
#
# For 270th warehouse, selected products' values are:
# [266.35, 57.77, 206.72, 127.3, 126.94, 166.35, 30.99, 117.98, 17.5, 9.48, 1.69]
#
# For 270th warehouse, The Total Weight is: 649.0
# For 270th warehouse, The Total Value is: 1129.07
# For 271th warehouse, selected products are:
# [47, 21, 37, 26, 45, 20, 39, 19, 44]
#
# For 271th warehouse, selected products' weights are:
# [114.0, 44.0, 85.0, 109.0, 64.0, 110.0, 117.0, 6.0, 1.0]
#
# For 271th warehouse, selected products' values are:
# [243.99, 88.83, 147.64, 187.25, 108.47, 183.91, 194.39, 9.85, 0.5]
#
# For 271th warehouse, The Total Weight is: 650.0
# For 271th warehouse, The Total Value is: 1164.83
# For 272th warehouse, selected products are:
# [6, 46, 10, 2, 5, 8, 30, 22, 32, 35, 13]
#
# For 272th warehouse, selected products' weights are:
# [65.0, 108.0, 34.0, 122.0, 110.0, 122.0, 34.0, 30.0, 12.0, 8.0, 3.0]
#
# For 272th warehouse, selected products' values are:
# [129.08, 213.75, 63.17, 206.96, 175.65, 188.24, 52.4, 45.43, 16.28, 6.06, 1.71]
#
# For 272th warehouse, The Total Weight is: 648.0
# For 272th warehouse, The Total Value is: 1098.73
# For 273th warehouse, selected products are:
# [43, 27, 46, 31, 12, 48, 24, 33, 42, 2, 28, 20, 8, 38, 26, 14]
#
# For 273th warehouse, selected products' weights are:
# [34.0, 37.0, 17.0, 118.0, 38.0, 18.0, 40.0, 41.0, 32.0, 57.0, 83.0, 65.0, 58.0, 4.0, 2.0, 2.0]
#
# For 273th warehouse, selected products' values are:
# [71.78, 75.83, 34.51, 228.24, 65.62, 30.18, 64.71, 66.06, 50.5, 87.0, 119.48, 92.71, 80.93, 4.89, 2.17, 1.6]
#
# For 273th warehouse, The Total Weight is: 646.0
# For 273th warehouse, The Total Value is: 1076.2100000000003
# For 274th warehouse, selected products are:
# [47, 10, 39, 28, 11, 12, 46, 31, 44, 5, 19, 13, 14, 9]
#
# For 274th warehouse, selected products' weights are:
# [25.0, 59.0, 52.0, 64.0, 20.0, 20.0, 87.0, 96.0, 48.0, 117.0, 36.0, 9.0, 8.0, 6.0]
#
# For 274th warehouse, selected products' values are:
# [47.86, 111.56, 93.96, 108.36, 32.42, 31.62, 136.68, 149.81, 67.36, 159.59, 49.07, 12.11, 9.0, 1.04]
#
# For 274th warehouse, The Total Weight is: 647.0
# For 274th warehouse, The Total Value is: 1010.44
# For 275th warehouse, selected products are:
# [25, 3, 27, 17, 4, 35, 6, 18, 15, 44, 45, 49, 19, 21]
#
# For 275th warehouse, selected products' weights are:
# [9.0, 31.0, 117.0, 4.0, 42.0, 122.0, 51.0, 23.0, 24.0, 19.0, 100.0, 74.0, 33.0, 1.0]
#
# For 275th warehouse, selected products' values are:
# [20.42, 67.44, 211.99, 7.08, 71.68, 196.74, 77.77, 34.08, 35.38, 27.85, 145.14, 87.79, 37.38, 1.13]
#
# For 275th warehouse, The Total Weight is: 650.0
# For 275th warehouse, The Total Value is: 1021.87
# For 276th warehouse, selected products are:
# [28, 18, 20, 22, 49, 13, 47, 21, 11, 3, 36]
#
# For 276th warehouse, selected products' weights are:
# [110.0, 123.0, 21.0, 72.0, 107.0, 14.0, 27.0, 108.0, 53.0, 10.0, 1.0]
#
# For 276th warehouse, selected products' values are:
# [240.8, 232.35, 36.91, 123.26, 172.76, 22.42, 41.6, 160.7, 76.67, 12.17, 0.86]
#
# For 276th warehouse, The Total Weight is: 646.0
# For 276th warehouse, The Total Value is: 1120.5
# For 277th warehouse, selected products are:
# [15, 25, 23, 2, 39, 49, 44, 34, 16, 17, 10, 18, 22]
#
# For 277th warehouse, selected products' weights are:
# [36.0, 63.0, 51.0, 31.0, 26.0, 86.0, 115.0, 41.0, 45.0, 72.0, 8.0, 73.0, 3.0]
#
# For 277th warehouse, selected products' values are:
# [70.42, 107.56, 85.95, 50.75, 41.56, 123.0, 164.12, 54.91, 58.2, 92.83, 9.9, 88.39, 2.32]
#
# For 277th warehouse, The Total Weight is: 650.0
# For 277th warehouse, The Total Value is: 949.9100000000001
# For 278th warehouse, selected products are:
# [0, 25, 7, 11, 28, 24, 22, 27, 5, 43, 6]
#
# For 278th warehouse, selected products' weights are:
# [74.0, 45.0, 74.0, 25.0, 95.0, 8.0, 122.0, 101.0, 86.0, 18.0, 1.0]
#
# For 278th warehouse, selected products' values are:
# [186.78, 95.91, 150.1, 49.21, 169.51, 13.54, 206.36, 170.66, 139.78, 25.99, 1.05]
#
# For 278th warehouse, The Total Weight is: 649.0
# For 278th warehouse, The Total Value is: 1208.8899999999999
# For 279th warehouse, selected products are:
# [38, 32, 18, 14, 42, 41, 39, 31, 47, 30, 22, 28, 0, 2, 1]
#
# For 279th warehouse, selected products' weights are:
# [10.0, 21.0, 38.0, 35.0, 11.0, 120.0, 124.0, 115.0, 22.0, 1.0, 107.0, 24.0, 4.0, 14.0, 1.0]
#
# For 279th warehouse, selected products' values are:
# [18.95, 34.81, 62.17, 54.7, 17.1, 183.46, 187.75, 172.14, 32.56, 1.48, 155.42, 33.01, 4.86, 14.05, 0.68]
#
# For 279th warehouse, The Total Weight is: 647.0
# For 279th warehouse, The Total Value is: 973.14
# For 280th warehouse, selected products are:
# [41, 30, 5, 24, 6, 22, 44, 16, 23, 17, 31, 26, 39, 4, 46]
#
# For 280th warehouse, selected products' weights are:
# [87.0, 18.0, 92.0, 10.0, 119.0, 80.0, 10.0, 57.0, 93.0, 47.0, 2.0, 1.0, 20.0, 9.0, 4.0]
#
# For 280th warehouse, selected products' values are:
# [178.28, 30.06, 150.11, 14.79, 168.05, 108.46, 13.4, 74.09, 118.02, 58.2, 2.4, 1.19, 22.89, 9.52, 2.7]
#
# For 280th warehouse, The Total Weight is: 649.0
# For 280th warehouse, The Total Value is: 952.1600000000002
# For 281th warehouse, selected products are:
# [20, 7, 10, 40, 19, 46, 41, 31, 49, 36, 38, 28, 8, 22, 24]
#
# For 281th warehouse, selected products' weights are:
# [79.0, 14.0, 83.0, 10.0, 44.0, 39.0, 37.0, 32.0, 22.0, 84.0, 13.0, 75.0, 70.0, 34.0, 13.0]
#
# For 281th warehouse, selected products' values are:
# [164.88, 28.16, 153.14, 17.77, 77.37, 65.57, 61.33, 51.66, 35.15, 133.21, 20.0, 110.76, 102.68, 41.01, 11.35]
#
# For 281th warehouse, The Total Weight is: 649.0
# For 281th warehouse, The Total Value is: 1074.0399999999997
# For 282th warehouse, selected products are:
# [0, 22, 4, 7, 32, 44, 37, 8, 30, 19, 15, 11, 47]
#
# For 282th warehouse, selected products' weights are:
# [105.0, 84.0, 77.0, 88.0, 11.0, 107.0, 19.0, 73.0, 11.0, 36.0, 25.0, 8.0, 2.0]
#
# For 282th warehouse, selected products' values are:
# [205.94, 156.0, 138.08, 136.81, 16.4, 157.99, 26.42, 99.4, 14.0, 45.44, 31.06, 9.91, 1.93]
#
# For 282th warehouse, The Total Weight is: 646.0
# For 282th warehouse, The Total Value is: 1039.3799999999999
# For 283th warehouse, selected products are:
# [2, 49, 12, 43, 34, 22, 46, 40, 16, 45, 18, 10, 17]
#
# For 283th warehouse, selected products' weights are:
# [48.0, 19.0, 54.0, 93.0, 54.0, 93.0, 60.0, 63.0, 40.0, 113.0, 1.0, 3.0, 4.0]
#
# For 283th warehouse, selected products' values are:
# [94.71, 34.83, 90.01, 149.33, 79.85, 136.25, 86.02, 88.92, 55.28, 154.36, 1.23, 3.62, 4.71]
#
# For 283th warehouse, The Total Weight is: 645.0
# For 283th warehouse, The Total Value is: 979.12
# For 284th warehouse, selected products are:
# [28, 23, 6, 48, 37, 25, 19, 20, 17, 16, 13, 4, 12, 10]
#
# For 284th warehouse, selected products' weights are:
# [79.0, 41.0, 24.0, 50.0, 78.0, 31.0, 82.0, 39.0, 60.0, 88.0, 24.0, 38.0, 5.0, 2.0]
#
# For 284th warehouse, selected products' values are:
# [149.85, 72.13, 41.0, 85.07, 125.99, 48.91, 127.29, 59.69, 91.23, 128.55, 34.51, 52.5, 6.86, 2.13]
#
# For 284th warehouse, The Total Weight is: 641.0
# For 284th warehouse, The Total Value is: 1025.71
# For 285th warehouse, selected products are:
# [17, 48, 8, 16, 27, 30, 15, 21, 31, 25, 47]
#
# For 285th warehouse, selected products' weights are:
# [79.0, 112.0, 79.0, 89.0, 114.0, 7.0, 62.0, 59.0, 33.0, 10.0, 5.0]
#
# For 285th warehouse, selected products' values are:
# [184.87, 245.95, 157.23, 172.72, 215.74, 13.08, 112.22, 105.77, 57.49, 13.65, 6.79]
#
# For 285th warehouse, The Total Weight is: 649.0
# For 285th warehouse, The Total Value is: 1285.51
# For 286th warehouse, selected products are:
# [25, 14, 31, 37, 18, 41, 22]
#
# For 286th warehouse, selected products' weights are:
# [61.0, 95.0, 83.0, 116.0, 92.0, 112.0, 84.0]
#
# For 286th warehouse, selected products' values are:
# [126.97, 196.27, 153.39, 212.84, 168.72, 191.59, 136.72]
#
# For 286th warehouse, The Total Weight is: 643.0
# For 286th warehouse, The Total Value is: 1186.5
# For 287th warehouse, selected products are:
# [9, 6, 8, 14, 3, 43, 30, 49, 17, 4, 13]
#
# For 287th warehouse, selected products' weights are:
# [114.0, 7.0, 90.0, 124.0, 21.0, 102.0, 46.0, 107.0, 19.0, 14.0, 6.0]
#
# For 287th warehouse, selected products' values are:
# [212.21, 12.78, 142.95, 189.9, 31.69, 147.76, 65.65, 152.5, 26.39, 18.34, 7.18]
#
# For 287th warehouse, The Total Weight is: 650.0
# For 287th warehouse, The Total Value is: 1007.35
# For 288th warehouse, selected products are:
# [31, 24, 35, 36, 5, 29, 2, 27, 7, 38, 15, 45]
#
# For 288th warehouse, selected products' weights are:
# [40.0, 99.0, 54.0, 75.0, 56.0, 51.0, 70.0, 107.0, 18.0, 65.0, 7.0, 5.0]
#
# For 288th warehouse, selected products' values are:
# [116.42, 209.14, 100.91, 134.83, 97.76, 87.66, 117.87, 171.31, 27.67, 98.9, 8.29, 5.63]
#
# For 288th warehouse, The Total Weight is: 647.0
# For 288th warehouse, The Total Value is: 1176.3900000000003
# For 289th warehouse, selected products are:
# [40, 39, 7, 21, 36, 42, 25, 14, 33, 30, 24, 49, 13, 27]
#
# For 289th warehouse, selected products' weights are:
# [83.0, 41.0, 27.0, 63.0, 64.0, 9.0, 39.0, 91.0, 65.0, 68.0, 73.0, 14.0, 3.0, 5.0]
#
# For 289th warehouse, selected products' values are:
# [200.31, 81.76, 47.39, 108.1, 106.39, 14.96, 63.63, 146.88, 104.32, 104.42, 106.17, 19.65, 3.42, 1.65]
#
# For 289th warehouse, The Total Weight is: 645.0
# For 289th warehouse, The Total Value is: 1109.0500000000002
# For 290th warehouse, selected products are:
# [22, 24, 19, 31, 17, 45, 2, 35, 33, 37, 30]
# For 290th warehouse, selected products' weights are:
# [124.0, 118.0, 124.0, 91.0, 90.0, 63.0, 7.0, 12.0, 3.0, 4.0, 8.0]
#
# For 290th warehouse, selected products' values are:
# [255.68, 229.7, 239.38, 172.4, 162.66, 99.89, 10.13, 14.32, 3.48, 3.26, 6.15]
#
# For 290th warehouse, The Total Weight is: 644.0
# For 290th warehouse, The Total Value is: 1197.0500000000002
# For 291th warehouse, selected products are:
# [45, 16, 19, 14, 10, 25, 34, 26, 41, 40, 43, 30, 36, 48, 2, 24, 37]
#
# For 291th warehouse, selected products' weights are:
# [29.0, 81.0, 29.0, 8.0, 93.0, 17.0, 18.0, 87.0, 40.0, 68.0, 69.0, 6.0, 14.0, 33.0, 36.0, 6.0, 10.0]
#
# For 291th warehouse, selected products' values are:
# [61.76, 163.09, 57.36, 15.81, 180.24, 32.12, 30.12, 142.23, 64.17, 107.53, 102.75, 8.45, 18.67, 42.97, 45.29, 6.56, 5.31]
#
# For 291th warehouse, The Total Weight is: 644.0
# For 291th warehouse, The Total Value is: 1084.4299999999998
# For 292th warehouse, selected products are:
# [41, 43, 1, 2, 40, 32, 9, 38, 44, 30, 48, 24, 47]
#
# For 292th warehouse, selected products' weights are:
# [61.0, 55.0, 105.0, 122.0, 38.0, 47.0, 49.0, 89.0, 3.0, 30.0, 10.0, 19.0, 13.0]
#
# For 292th warehouse, selected products' values are:
# [116.77, 100.74, 186.85, 213.47, 61.61, 76.04, 78.74, 130.75, 4.35, 42.05, 12.54, 23.64, 9.17]
#
# For 292th warehouse, The Total Weight is: 641.0
# For 292th warehouse, The Total Value is: 1056.72
# For 293th warehouse, selected products are:
# [25, 31, 9, 38, 21, 27, 7, 32, 11, 12, 20, 29, 14, 49, 3]
#
# For 293th warehouse, selected products' weights are:
# [73.0, 71.0, 62.0, 43.0, 35.0, 16.0, 69.0, 57.0, 20.0, 50.0, 73.0, 73.0, 1.0, 6.0, 1.0]
#
# For 293th warehouse, selected products' values are:
# [177.87, 171.76, 147.08, 92.07, 74.36, 30.15, 124.52, 102.12, 34.88, 81.42, 118.86, 106.34, 1.31, 5.15, 0.8]
#
# For 293th warehouse, The Total Weight is: 650.0
# For 293th warehouse, The Total Value is: 1268.6899999999998
# For 294th warehouse, selected products are:
# [38, 13, 6, 23, 41, 2, 1, 25, 12, 32, 39, 33]
#
# For 294th warehouse, selected products' weights are:
# [93.0, 72.0, 109.0, 8.0, 86.0, 115.0, 81.0, 11.0, 13.0, 27.0, 32.0, 2.0]
#
# For 294th warehouse, selected products' values are:
# [199.89, 140.5, 207.61, 14.6, 153.75, 202.58, 134.14, 16.96, 19.37, 35.24, 35.54, 1.26]
#
# For 294th warehouse, The Total Weight is: 649.0
# For 294th warehouse, The Total Value is: 1161.44
# For 295th warehouse, selected products are:
# [3, 31, 45, 8, 10, 37, 41, 17, 34, 42, 27, 23, 43, 40]
#
# For 295th warehouse, selected products' weights are:
# [36.0, 34.0, 7.0, 22.0, 91.0, 117.0, 32.0, 93.0, 59.0, 3.0, 42.0, 71.0, 18.0, 24.0]
#
# For 295th warehouse, selected products' values are:
# [70.58, 58.15, 11.92, 35.72, 144.06, 183.21, 48.26, 140.03, 80.68, 3.79, 52.64, 88.71, 19.94, 25.05]
#
# For 295th warehouse, The Total Weight is: 649.0
# For 295th warehouse, The Total Value is: 962.7399999999999
# For 296th warehouse, selected products are:
# [44, 38, 9, 31, 11, 22, 49, 37, 15, 12, 26, 45, 10]
#
# For 296th warehouse, selected products' weights are:
# [62.0, 60.0, 98.0, 104.0, 29.0, 107.0, 9.0, 52.0, 36.0, 23.0, 47.0, 15.0, 8.0]
#
# For 296th warehouse, selected products' values are:
# [106.3, 93.28, 140.38, 146.25, 40.48, 136.96, 11.42, 64.86, 44.28, 27.47, 55.37, 17.41, 4.34]
#
# For 296th warehouse, The Total Weight is: 650.0
# For 296th warehouse, The Total Value is: 888.8
# For 297th warehouse, selected products are:
# [26, 19, 48, 20, 32, 33, 10, 16, 41, 39, 34, 35]
#
# For 297th warehouse, selected products' weights are:
# [94.0, 23.0, 30.0, 35.0, 9.0, 72.0, 42.0, 117.0, 50.0, 119.0, 47.0, 5.0]
#
# For 297th warehouse, selected products' values are:
# [194.85, 44.5, 50.49, 58.04, 14.08, 111.56, 64.37, 177.69, 75.51, 173.61, 67.0, 6.42]
#
# For 297th warehouse, The Total Weight is: 643.0
# For 297th warehouse, The Total Value is: 1038.12
# For 298th warehouse, selected products are:
# [43, 6, 25, 3, 30, 24, 0, 28, 22, 2]
#
# For 298th warehouse, selected products' weights are:
# [78.0, 91.0, 93.0, 13.0, 104.0, 105.0, 44.0, 74.0, 20.0, 21.0]
#
# For 298th warehouse, selected products' values are:
# [220.74, 184.32, 174.37, 22.06, 174.12, 174.02, 72.16, 117.82, 30.25, 30.97]
#
# For 298th warehouse, The Total Weight is: 643.0
# For 298th warehouse, The Total Value is: 1200.83
# For 299th warehouse, selected products are:
# [10, 31, 7, 22, 18, 49, 26, 12, 20, 45, 24, 32, 4, 36]
#
# For 299th warehouse, selected products' weights are:
# [97.0, 113.0, 76.0, 66.0, 123.0, 52.0, 59.0, 28.0, 5.0, 11.0, 13.0, 2.0, 3.0, 2.0]
#
# For 299th warehouse, selected products' values are:
# [243.9, 227.56, 152.4, 126.52, 217.68, 86.81, 90.46, 42.4, 6.96, 14.4, 16.12, 2.1, 3.14, 1.75]
#
# For 299th warehouse, The Total Weight is: 650.0
# For 299th warehouse, The Total Value is: 1232.2

# %%
# Check the code above
print(warehouse_value)         
# Print the warehouse_value generated
# Out:
# {0: [650.0, 1076.2699999999998, None], 1: [648.0, 976.78, None], 2: [644.0, 1231.7, None], 3: [649.0, 1003.49, None], 4: [645.0, 1099.9699999999998, None], 5: [650.0, 1009.1800000000001, None], 6: [648.0, 1196.45, None], 7: [647.0, 975.1199999999998, None], 8: [648.0, 1009.3899999999999, None], 9: [649.0, 1054.0, None], 10: [646.0, 948.0300000000001, None], 11: [648.0, 1102.16, None], 12: [648.0, 1133.1200000000001, None], 13: [645.0, 1110.6799999999998, None], 14: [644.0, 938.1499999999999, None], 15: [634.0, 1059.3, None], 16: [650.0, 1174.3899999999999, None], 17: [649.0, 997.1700000000001, None], 18: [641.0, 998.0699999999999, None], 19: [642.0, 986.91, None], 20: [650.0, 1221.07, None], 21: [649.0, 1032.8500000000001, None], 22: [648.0, 1046.92, None], 23: [649.0, 1076.2299999999998, None], 24: [647.0, 1090.61, None], 25: [650.0, 1074.56, None], 26: [649.0, 1050.9099999999999, None], 27: [649.0, 1079.3599999999997, None], 28: [646.0, 1040.3299999999997, None], 29: [647.0, 1063.54, None], 30: [638.0, 1036.1399999999999, None], 31: [650.0, 1019.95, None], 32: [647.0, 1127.27, None], 33: [646.0, 1205.91, None], 34: [647.0, 993.1199999999999, None], 35: [639.0, 1078.94, None], 36: [650.0, 1029.0399999999997, None], 37: [641.0, 1221.1200000000001, None], 38: [649.0, 1099.67, None], 39: [647.0, 1114.26, None], 40: [650.0, 1144.0900000000001, None], 41: [650.0, 1007.43, None], 42: [649.0, 1057.57, None], 43: [650.0, 1158.73, None], 44: [647.0, 1079.43, None], 45: [647.0, 1120.63, None], 46: [649.0, 1182.0400000000002, None], 47: [650.0, 1059.2500000000002, None], 48: [650.0, 1085.1900000000003, None], 49: [641.0, 1088.89, None], 50: [650.0, 1057.04, None], 51: [650.0, 1225.8700000000001, None], 52: [646.0, 915.6199999999999, None], 53: [641.0, 1011.2800000000002, None], 54: [650.0, 1039.8399999999997, None], 55: [649.0, 1130.57, None], 56: [648.0, 1013.58, None], 57: [650.0, 1088.36, None], 58: [646.0, 1095.93, None], 59: [636.0, 1078.29, None], 60: [646.0, 1058.07, None], 61: [650.0, 1061.11, None], 62: [648.0, 1034.35, None], 63: [648.0, 1180.4800000000002, None], 64: [649.0, 1002.03, None], 65: [648.0, 1197.9299999999998, None], 66: [649.0, 966.4899999999998, None], 67: [649.0, 986.0699999999999, None], 68: [648.0, 1168.5000000000002, None], 69: [642.0, 1073.29, None], 70: [649.0, 1135.8300000000002, None], 71: [638.0, 1000.9399999999998, None], 72: [650.0, 1061.4899999999998, None], 73: [650.0, 1208.64, None], 74: [650.0, 1175.79, None], 75: [649.0, 1000.5899999999999, None], 76: [647.0, 988.4100000000001, None], 77: [647.0, 1030.2600000000004, None], 78: [647.0, 974.5400000000001, None], 79: [650.0, 983.6599999999999, None], 80: [647.0, 1117.85, None], 81: [644.0, 1030.5300000000002, None], 82: [650.0, 1099.8600000000001, None], 83: [649.0, 974.24, None], 84: [648.0, 1131.44, None], 85: [641.0, 1122.62, None], 86: [650.0, 1086.02, None], 87: [650.0, 1110.8199999999997, None], 88: [648.0, 1022.2700000000002, None], 89: [649.0, 1054.96, None], 90: [647.0, 941.02, None], 91: [650.0, 1186.65, None], 92: [650.0, 1048.9399999999998, None], 93: [649.0, 1014.97, None], 94: [649.0, 1066.64, None], 95: [642.0, 1046.01, None], 96: [649.0, 939.2999999999998, None], 97: [643.0, 984.3000000000001, None], 98: [650.0, 968.1599999999999, None], 99: [648.0, 1076.85, None], 100: [647.0, 1081.91, None], 101: [643.0, 993.98, None], 102: [647.0, 1067.1000000000001, None], 103: [643.0, 1047.7700000000002, None], 104: [646.0, 1036.42, None], 105: [648.0, 1098.24, None], 106: [649.0, 1045.74, None], 107: [650.0, 1051.5600000000002, None], 108: [649.0, 1024.45, None], 109: [650.0, 1210.65, None], 110: [645.0, 1043.38, None], 111: [649.0, 1095.6799999999998, None], 112: [647.0, 1039.9499999999998, None], 113: [649.0, 1134.43, None], 114: [650.0, 1020.1200000000003, None], 115: [643.0, 1003.11, None], 116: [646.0, 985.6200000000001, None], 117: [650.0, 1143.2, None], 118: [647.0, 960.99, None], 119: [641.0, 1082.8999999999999, None], 120: [647.0, 1104 ...

# %% [markdown]
# ## Problem 2: Top Alternative Selections
#
# In this problem, you will simulate the cross-warehouse-transshipment solutions when a random warehouse is out-of-stock during the promotion period.

# %% [markdown]
# ### Step 1: Generate the 300*300 distance matrix and write the results to "Distances.csv"
# Let's generate a distance matrix among the 300 warehouses first. Each of the distances can be generated by using a normal distribution with a mean of 500 and a standard deviation of 300.
#
# Be careful, all the distances generated should be positive numbers and should be rounded to integers using the round() function. After successfully generating the distance matrix, please write it to a new CSV file called “Distances.csv”.

# %%
# Generate the Distance matrix 300*300

#write your codes here
def gen_matrix(matrix_size, random_seed):  # matrix_size here is a height(=or a width) of a square matrix
    
    # Generate distance_numbers randomly
    number_of_distances = sum([i for i in range(matrix_size)])  # the number of distances needed to fill the given sized matrix
    np.random.seed(random_seed)  # use the input of random_seed 
    distance_numbers = np.random.normal(500, 300, (number_of_distances))  # generate random numbers with the given condition
    distance_numbers = [round(np.abs(i)) for i in distance_numbers]  # convert the above to positive integers
    
    # Generate 'matrix_1' filled with zeros
    matrix_1 = np.zeros((matrix_size, matrix_size), dtype = int)
    
    # Fill the upper right corner of 'matrix_1'
    distance_index = 0
        
    for i in range(matrix_size):
        for j in range(matrix_size):
            if j > i:
                matrix_1[i][j] = distance_numbers[distance_index]
                distance_index += 1
    
    # Generate 'matrix_2' by transposing 'matrix_1'
    matrix_2 = matrix_1.T
    
    # Generate 'final_matrix' with the two matrices
    matrix_final = matrix_1 + matrix_2
    
    # Return 'final_matrix'
    return matrix_final

# %%
# Check the code above
distances = gen_matrix(300, 0)
distances  
# Show the distance matrix you generated 
# Check your maxtrix and see if all numbers are positive and rounded to integer
# Out:
# array([[   0, 1029,  620, ...,  529,  675,  380],
#        [1029,    0,  611, ...,  606,  614,  359],
#        [ 620,  611,    0, ...,  642,  779,  447],
#        ...,
#        [ 529,  606,  642, ...,    0,  543,  632],
#        [ 675,  614,  779, ...,  543,    0,  329],
#        [ 380,  359,  447, ...,  632,  329,    0]])

# %% [markdown]
# Now we are going to save the file in 'Distance.csv'

# %%
f = open("Distances.csv", "w") # We will create this file.

#write your codes here
for i in distances:
    for j in i:
        f.write(f"{str(j)},")
    f.write("\n")

f.close()

# %% [markdown]
# ### Step2：Select the Alternative Warehouse ("Helper")

# %% [markdown]
# Marlon randomly selects No.p warehouse that is out-of-stock in this simulation.

# %%
'''p is offered by Malron. Do not change the code below.'''

p=np.random.randint(0,300) 
p
# Out:
# 159

# %% [markdown]
# There are 3 things to do:
# 1. Based on the generated p, find the corresponding distance between this warehouse No.p and each of the other Helpers from the distance matrix you generated in Step 1 of Problem 2.
# 2. Find the corresponding total value and total weight of all products stored in each Helper (you have calculated these numbers in Problem 1).
# 3. Calculate the “Value_per_Weight” ratio for each Helper, sort the ratio in descending order and choose top helpers with 10 highest “Value_per_Weight”ratios.
#
# ###  $Value\_per\_Weight = \frac{Total\_Value}{Total\_Weight}-Distance\times\ Transpotation\_Cost$
#
# #### Note that you are not allowed to use dynamic programming in this problem!

# %%
#write your codes here

# Update the last place of 'warehouse_value' (that we left as 'None') with value-per-weight between p and i
for i in range(300):
    
    if i != p:
        i_distance = distances[p][i]
        i_total_weight = warehouse_value[i][0]
        i_total_value = warehouse_value[i][1]
        i_value_per_weight = (i_total_value / i_total_weight) - i_distance * 0.015
        
        # Update the last place with value-per-weight between p and i 
        warehouse_value[i][-1] = i_value_per_weight  
        
    else:
        # Update the last place with a very small number to prevent a warehouse from showing itself as a helper
        warehouse_value[i][-1] = (-float('inf'))  

# Flip keys, values of 'warehouse_value'
warehouse_value_flipped = {value[-1]: key for key, value in warehouse_value.items()}

# Find the top 10 helpers
helpers_sorted = sorted(warehouse_value_flipped, reverse=True)

# Check if 'helpers_sorted' has any duplicate values
if len(helpers_sorted) == len(set(helpers_sorted)):
    
    # Final output
    top_10_helpers = []     
    for i in helpers_sorted[:10]:
        top_10_helpers.append((warehouse_value_flipped[i], i))
else:
    print("Warning: Duplicate values in value-per-weight")

# %%
# Check the code above
top_10_helpers
# Show the cross-warehouse-transshipment solution when No.p warehouse is out-of-stock during the promotion period. 
# The solution should contain Helper indexes and the corresponding "Value_Per_Weight" ratios.
# Out:
# [(299, 1.7006923076923077),
#  (129, 1.5063888888888894),
#  (162, 1.462984615384615),
#  (222, 1.4182071097372488),
#  (211, 1.2470743034055731),
#  (258, 1.0124000000000004),
#  (287, 1.0097692307692308),
#  (186, 0.9439767441860467),
#  (212, 0.9138461538461542),
#  (251, 0.8620743034055727)]

# %% [markdown]
# #### Note: Due to random assignment of No.p warehouse, it's acceptable if your recommended solution changes each time you re-run the code.

# %% [markdown]
# ### Submision Requirement: Please submit all files (Distances.csv, and Fall21_Mid_Walmart.ipynb files) as one zip file on Canvas. Please add SIDs and first names of all teammates on the name of zip file. For example, Zhack_14325_Allen_34672_Alex_12345.zip.
